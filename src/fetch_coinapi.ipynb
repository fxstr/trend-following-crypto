# %% [markdown]
# Why Coinapi?
# - Delisted symbols
# - Long history (back to the origins)
# - Cleaned data
# - Pricing quite fair and usage-based (Coinmarketcap costs $700/month for the same)

# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
from datetime import datetime, date
import os
from matplotlib import pyplot as plt
import coinapi_fetcher
import time
from dotenv import load_dotenv

load_dotenv()

exchange = os.getenv('COINAPI_EXCHANGE')
base_currency = os.getenv('COINAPI_BASE_CURRENCY')

output_folder = f'../{exchange.lower()}_data/'
print(f'Store files in {output_folder}')
# Out:
# Store files in ../binance_data/

# %%
# btc = coinapi_fetcher.get_history('COINBASE_SPOT_BTC_USD', datetime(2010, 1, 1))
# btc['close'].plot(figsize=(15, 6))
# plt.show()
# btc.to_csv(os.path.join(output_folder, 'COINBASE_SPOT_BTC_USD.csv'), index=True)

# %%
# Binance doesn't have base currency USD; use BTC and re-caculate (BINANCE has a market share
# of approx 40%)
# Problem: There is no BTC-BTC, so we don't get the BTC volume. Use Coinbase instead, as they
# directly quote USD.
exchange_id = exchange
active = coinapi_fetcher.get_active_symbols(exchange_id, base_currency=base_currency)
historical = coinapi_fetcher.get_historical_symbols(exchange_id, base_currency=base_currency)
symbols_to_fetch = list(set(active + historical))

print(f'Got {len(active)} active and {len(historical)} historical, {len(symbols_to_fetch)} total symbols')
# Out:
# Get active symbols for BINANCE
# Sample response item keys: ['symbol_id', 'exchange_id', 'symbol_type', 'asset_id_base', 'asset_id_quote', 'data_start', 'data_end', 'data_quote_start', 'data_quote_end', 'data_orderbook_start', 'data_orderbook_end', 'data_trade_start', 'data_trade_end', 'volume_1hrs', 'volume_1hrs_usd', 'volume_1day', 'volume_1day_usd', 'volume_1mth', 'volume_1mth_usd', 'price', 'symbol_id_exchange', 'asset_id_base_exchange', 'asset_id_quote_exchange', 'price_precision', 'size_precision', 'raw_kvp', 'volume_to_usd', 'symbol_id_int']
# Sample response item: {'symbol_id': 'BINANCE_SPOT_UNI_USDT', 'exchange_id': 'BINANCE', 'symbol_type': 'SPOT', 'asset_id_base': 'UNI', 'asset_id_quote': 'USDT', 'data_start': '2020-09-17', 'data_end': '2026-04-13', 'data_quote_start': '2020-09-17T00:00:00.0000000Z', 'data_quote_end': '2026-04-13T00:00:00.0000000Z', 'data_orderbook_start': '2020-09-17T00:00:00.0000000Z', 'data_orderbook_end': '2026-04-13T00:00:00.0000000Z', 'data_trade_start': '2020-09-17T00:00:00.0000000Z', 'data_trade_end': '2026-04-13T00:00:00.0000000Z', 'volume_1hrs': 43374.49, 'volume_1hrs_usd': 133667.24, 'volume_1day': 3429320.14, 'volume_1day_usd': 10568141.68, 'volume_1mth': 101133984.19999994, 'volume_1mth_usd': 311664770.36, 'price': 3.0805, 'symbol_id_exchange': 'UNIUSDT', 'asset_id_base_exchange': 'UNI', 'asset_id_quote_exchange': 'USDT', 'price_precision': 0.001, 'size_precision': 0.01, 'raw_kvp': {'symbol': 'UNIUSDT', 'deliveryDate': '0', 'onboardDate': '0', 'status': 'TRADING', 'baseAsset': 'UNI', 'quoteAsset': 'USDT', 'pricePrecision': '0', 'quantityPrecision': '0', 'baseAssetPrecision': '8', 'quotePrecision': '8', 'settlePlan': '0', 'filters': '[{"minPrice":"0.00100000","maxPrice":"10000.00000000","filterType":"PRICE_FILTER","tickSize":"0.00100000","stepSize":null,"maxQty":null,"minQty":null,"limit":0,"notional":null,"multiplierDown":null,"multiplierUp":null,"multiplierDecimal":null},{"minPrice":null,"maxPrice":null,"filterType":"LOT_SIZE","tickSize":null,"stepSize":"0.01000000","maxQty":"90000.00000000","minQty":"0.01000000","limit":0,"notional":null,"multiplierDown":null,"multiplierUp":null,"multiplierDecimal":null},{"minPrice":null,"maxPrice":null,"filterType":"ICEBERG_PARTS","tickSize":null,"stepSize":null,"maxQty":null,"minQty":null,"limit":100,"notional":null,"multiplierDown":null,"multiplierUp":null,"multiplierDecimal":null},{"minPrice":null,"maxPrice":null,"filterType":"MARKET_LOT_SIZE","tickSize":null,"stepSize":"0.00000000","maxQty":"62033.98687500","minQty":"0.00000000","limit":0,"notional":null,"multiplierDown":null,"multiplierUp":null,"multiplierDecimal":null},{"minPrice":null,"maxPrice":null,"filterType":"TRAILING_DELTA","tickSize":null,"stepSize":null,"maxQty":null,"minQty":null,"limit":0,"notional":null,"multiplierDown":null,"multiplierUp":null,"multiplierDecimal":null},{"minPrice":null,"maxPrice":null,"filterType":"PERCENT_PRICE_BY_SIDE","tickSize":null,"stepSize":null,"maxQty":null,"minQty":null,"limit":0,"notional":null,"multiplierDown":null,"multiplierUp":null,"multiplierDecimal":null},{"minPrice":null,"maxPrice":null,"filterType":"NOTIONAL","tickSize":null,"stepSize":null,"maxQty":null,"minQty":null,"limit":0,"notional":null,"multiplierDown":null,"multiplierUp":null,"multiplierDecimal":null},{"minPrice":null,"maxPrice":null,"filterType":"MAX_NUM_ORDERS","tickSize":null,"stepSize":null,"maxQty":null,"minQty":null,"limit":0,"notional":null,"multiplierDown":null,"multiplierUp":null,"multiplierDecimal":null},{"minPrice":null,"maxPrice":null,"filterType":"MAX_NUM_ORDER_LISTS","tickSize":null,"stepSize":null,"maxQty":null,"minQty":null,"limit":0,"notional":null,"multiplierDown":null,"multiplierUp":null,"multiplierDecimal":null},{"minPrice":null,"maxPrice":null,"filterType":"MAX_NUM_ALGO_ORDERS","tickSize":null,"stepSize":null,"maxQty":null,"minQty":null,"limit":0,"notional":null,"multiplierDown":null,"multiplierUp":null,"multiplierDecimal":null},{"minPrice":null,"maxPrice":null,"filterType":"MAX_NUM_ORDER_AMENDS","tickSize":null,"stepSize":null,"maxQty":null,"minQty":null,"limit":0,"notional":null,"multiplierDown":null,"multiplierUp":null,"multiplierDecimal":null}]', 'orderTypes': '["LIMIT","LIMIT_MAKER","MARKET","STOP_LOSS","STOP_LOSS_LIMIT","TAKE_PROFIT","TAKE_PROFIT_LIMIT"]', '_type': 'SPOT'}, 'volume_to_usd': 3.081701693321134, 'symbol_id_int': 5904108}
# Get historical symbols for BINANCE, adding to 0 existing
# Out of 1000 historical, 177 are USDT-based
# Get historical symbols for BINANCE, adding to 177 existing
# Out of 1000 historical, 217 are USDT-based
# Get historical symbols for BINANCE, adding to 394 existing
# Out of 1000 historical, 163 are USDT-based
# Get historical symbols for BINANCE, adding to 557 existing
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[38], line 7
#       5 exchange_id = exchange
#       6 active = coinapi_fetcher.get_active_symbols(exchange_id, base_currency=base_currency)
# ----> 7 historical = coinapi_fetcher.get_historical_symbols(exchange_id, base_currency=base_currency)
#       8 symbols_to_fetch = list(set(active + historical))
#      10 print(f'Got {len(active)} active and {len(historical)} historical, {len(symbols_to_fetch)} total symbols')
#
# File ~/Documents/Aktien/Code/Python/2025-11-crypto/src/coinapi_fetcher.py:68, in get_historical_symbols(exchange_id, page, symbols, base_currency)
#      62 params = {
#      63     # 1k is the max allowed (or at least the max it returns)
#      64     'limit': 1000,
#      65     'page': page,
#      66 }
#      67 historical = get(f'https://rest.coinapi.io/v1/symbols/{exchange_id}/history', params)
# ---> 68 base_currency_history = [coin['symbol_id'] for coin in historical if coin['asset_id_quote'] == base_currency]
#      69 print(f'Out of {len(historical)} historical, {len(base_currency_history)} are {base_currency}-based')
#      70 all_symbols =  symbols + base_currency_history
#
# File ~/Documents/Aktien/Code/Python/2025-11-crypto/src/coinapi_fetcher.py:68, in get_historical_symbols(exchange_id, page, symbols, base_currency)
#      62 params = {
#      63     # 1k is the max allowed (or at least the max it returns)
#      64     'limit': 1000,
#      65     'page': page,
#      66 }
#      67 historical = get(f'https://rest.coinapi.io/v1/symbols/{exchange_id}/history', params)
# ---> 68 base_currency_history = [coin['symbol_id'] for coin in historical if coin['asset_id_quote'] == base_currency]
#      69 print(f'Out of {len(historical)} historical, {len(base_currency_history)} are {base_currency}-based')
#      70 all_symbols =  symbols + base_currency_history
#
# File ~/Documents/Aktien/Code/Python/2025-11-crypto/src/coinapi_fetcher.py:68, in get_historical_symbols(exchange_id, page, symbols, base_currency)
#      62 params = {
#      63     # 1k is the max allowed (or at least the max it returns)
#      64     'limit': 1000,
#      65     'page': page,
#      66 }
#      67 historical = get(f'https://rest.coinapi.io/v1/symbols/{exchange_id}/history', params)
# ---> 68 base_currency_history = [coin['symbol_id'] for coin in historical if coin['asset_id_quote'] == base_currency]
#      69 print(f'Out of {len(historical)} historical, {len(base_currency_history)} are {base_currency}-based')
#      70 all_symbols =  symbols + base_currency_history
#
# File ~/Documents/Aktien/Code/Python/2025-11-crypto/src/coinapi_fetcher.py:63, in get_historical_symbols(exchange_id, page, symbols, base_currency)
#      55 '''
#      56 Gets "delisted" symbols; needs pagination; returns their symbol_ids
#      57 '''
#      58 print(f'Get historical symbols for {exchange_id}, adding to {len(symbols)} existing')
#      59 params = {
#      60     # 1k is the max allowed (or at least the max it returns)
#      61     'limit': 1000,
#      62     'page': page,
# ---> 63 }
#      64 historical = get(f'https://rest.coinapi.io/v1/symbols/{exchange_id}/history', params)
#      65 base_currency_history = [coin['symbol_id'] for coin in historical if coin['asset_id_quote'] == base_currency]
#
# File <string>:4, in get(url, params)
#
# HTTPError: 500 Internal Server Error: {
#   "type": "https://tools.ietf.org/html/rfc7231#section-6.6.1",
#   "title": "Internal Server Error",
#   "status": 500,
#   "detail": "An error occurred while processing your request. Please try again later.",
#   "error": "Internal Server Error (An error occurred while processing your request. Please try again later.)",
#   "traceId": "f0ac870b5e345623db6fbb09b67f5708"
# }

# %%
def write_file(data, file_path):
    data.to_csv(file_path, index=True)
    print(f'Wrote file {file_path} with {len(data)} rows')

def get_existing_content(file_path):
    '''
    Returns the date of the last row in the file, if it exists, and its whole content (which
    is needed to append new data to later).
    '''
    if os.path.exists(file_path):
        print(f'File {file_path} exists, get last row')
        content = pd.read_csv(file_path)
        # When the file is empty, there's no 'date' column that we can use as index; return an
        # empty df so that all data is fetched from the crypto's start of existence.
        if ('date' not in content.columns):
            print('File is missing date column, return empty DataFrame')
            return (pd.DataFrame(), None)
        # Remove the last row; it may contain intraday data; make it 2 to be sure.
        content = content.iloc[:-2]
        content['date'] = pd.to_datetime(content['date'])
        content.set_index('date', inplace=True)
        print(f'Existing file has {len(content)} rows')
        if(len(content)):
            last_date = content.index[-1].date()
            print(f'Last date in existing file is {last_date}')
            return (content, last_date)
        return (content, None)
    else:
        return (pd.DataFrame(), None)

first_date = date(2010, 1, 1)

current_index = 0
total = len(symbols_to_fetch)
# Historical contains *all* cryptos, delisted as well as active. Delisted ones just won't return
# any new data.
for symbol_id in symbols_to_fetch:
    current_index += 1
    print('------')
    print(f'Get {current_index}/{total}')
    file_path = os.path.join(output_folder, 'historical', f'{symbol_id}.csv')
    (existing_content, start_date) = get_existing_content(file_path)
    if (start_date):
        print(f'File {symbol_id} exists, 2nd latest row\'s date is {start_date}')
    else:
        start_date = first_date
        print(f'File {symbol_id} does not exist')
    end_date = date.today()
    if (start_date >= end_date):
        print(f'Skip {symbol_id}, start is on or after end')
        continue
    print(f'Get {symbol_id} from {start_date} to {end_date}')
    new_content = coinapi_fetcher.get_history(symbol_id, start_date, end_date)
    # Make sure that content was returned before we concat an empty DF (which would fail)
    if (not new_content.empty):
        data = pd.concat([df for df in [existing_content, new_content] if not df.empty])
        write_file(data, file_path)
    time.sleep(0.5)
print(f'Out of {total} cryptos, {current_index} were fetched')
# Out:
# ------
# Get 1/660
# File ../binance_data/historical/BINANCE_SPOT_LISTA_USDT.csv exists, get last row
# Existing file has 660 rows
# Last date in existing file is 2026-04-11
# File BINANCE_SPOT_LISTA_USDT exists, 2nd latest row's date is 2026-04-11
# Get BINANCE_SPOT_LISTA_USDT from 2026-04-11 to 2026-04-13
# Fetching BINANCE_SPOT_LISTA_USDT from 2026-04-11 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_LISTA_USDT.csv with 662 rows
# ------
# Get 2/660
# File ../binance_data/historical/BINANCE_SPOT_1MBABYDOGE_USDT.csv exists, get last row
# Existing file has 572 rows
# Last date in existing file is 2026-04-11
# File BINANCE_SPOT_1MBABYDOGE_USDT exists, 2nd latest row's date is 2026-04-11
# Get BINANCE_SPOT_1MBABYDOGE_USDT from 2026-04-11 to 2026-04-13
# Fetching BINANCE_SPOT_1MBABYDOGE_USDT from 2026-04-11 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_1MBABYDOGE_USDT.csv with 574 rows
# ------
# Get 3/660
# File ../binance_data/historical/BINANCE_SPOT_ENS_USDT.csv exists, get last row
# Existing file has 1612 rows
# Last date in existing file is 2026-04-11
# File BINANCE_SPOT_ENS_USDT exists, 2nd latest row's date is 2026-04-11
# Get BINANCE_SPOT_ENS_USDT from 2026-04-11 to 2026-04-13
# Fetching BINANCE_SPOT_ENS_USDT from 2026-04-11 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ENS_USDT.csv with 1614 rows
# ------
# Get 4/660
# File ../binance_data/historical/BINANCE_SPOT_HEMI_USDT.csv exists, get last row
# Existing file has 200 rows
# Last date in existing file is 2026-04-11
# File BINANCE_SPOT_HEMI_USDT exists, 2nd latest row's date is 2026-04-11
# Get BINANCE_SPOT_HEMI_USDT from 2026-04-11 to 2026-04-13
# Fetching BINANCE_SPOT_HEMI_USDT from 2026-04-11 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_HEMI_USDT.csv with 202 rows
# ------
# Get 5/660
# File ../binance_data/historical/BINANCE_SPOT_PAXG_USDT.csv exists, get last row
# Existing file has 2045 rows
# Last date in existing file is 2026-04-05
# File BINANCE_SPOT_PAXG_USDT exists, 2nd latest row's date is 2026-04-05
# Get BINANCE_SPOT_PAXG_USDT from 2026-04-05 to 2026-04-13
# Fetching BINANCE_SPOT_PAXG_USDT from 2026-04-05 to 2026-04-13 …
# Fetched 8 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_PAXG_USDT.csv with 2053 rows
# ------
# Get 6/660
# File ../binance_data/historical/BINANCE_SPOT_BADGER_USDT.csv exists, get last row
# Existing file has 1504 rows
# Last date in existing file is 2025-04-15
# File BINANCE_SPOT_BADGER_USDT exists, 2nd latest row's date is 2025-04-15
# Get BINANCE_SPOT_BADGER_USDT from 2025-04-15 to 2026-04-13
# Fetching BINANCE_SPOT_BADGER_USDT from 2025-04-15 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BADGER_USDT.csv with 1506 rows
# ------
# Get 7/660
# File ../binance_data/historical/BINANCE_SPOT_ICX_USDT.csv exists, get last row
# Existing file has 2851 rows
# Last date in existing file is 2026-04-05
# File BINANCE_SPOT_ICX_USDT exists, 2nd latest row's date is 2026-04-05
# Get BINANCE_SPOT_ICX_USDT from 2026-04-05 to 2026-04-13
# Fetching BINANCE_SPOT_ICX_USDT from 2026-04-05 to 2026-04-13 …
# Fetched 8 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ICX_USDT.csv with 2859 rows
# ------
# Get 8/660
# File ../binance_data/historical/BINANCE_SPOT_BIFI_USDT.csv exists, get last row
# Existing file has 1470 rows
# Last date in existing file is 2026-04-11
# File BINANCE_SPOT_BIFI_USDT exists, 2nd latest row's date is 2026-04-11
# Get BINANCE_SPOT_BIFI_USDT from 2026-04-11 to 2026-04-13
# Fetching BINANCE_SPOT_BIFI_USDT from 2026-04-11 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BIFI_USDT.csv with 1472 rows
# ------
# Get 9/660
# File ../binance_data/historical/BINANCE_SPOT_TON_USDT.csv exists, get last row
# Existing file has 611 rows
# Last date in existing file is 2026-04-11
# File BINANCE_SPOT_TON_USDT exists, 2nd latest row's date is 2026-04-11
# Get BINANCE_SPOT_TON_USDT from 2026-04-11 to 2026-04-13
# Fetching BINANCE_SPOT_TON_USDT from 2026-04-11 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_TON_USDT.csv with 613 rows
# ------
# Get 10/660
# File ../binance_data/historical/BINANCE_SPOT_TRXUP_USDT.csv exists, get last row
# Existing file has 809 rows
# Last date in existing file is 2022-11-28
# File BINANCE_SPOT_TRXUP_USDT exists, 2nd latest row's date is 2022-11-28
# Get BINANCE_SPOT_TRXUP_USDT from 2022-11-28 to 2026-04-13
# Fetching BINANCE_SPOT_TRXUP_USDT from 2022-11-28 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_TRXUP_USDT.csv with 811 rows
# ------
# Get 11/660
# File ../binance_data/historical/BINANCE_SPOT_SEI_USDT.csv exists, get last row
# Existing file has 970 rows
# Last date in existing file is 2026-04-11
# File BINANCE_SPOT_SEI_USDT exists, 2nd latest row's date is 2026-04-11
# Get BINANCE_SPOT_SEI_USDT from 2026-04-11 to 2026-04-13
# Fetching BINANCE_SPOT_SEI_USDT from 2026-04-11 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_SEI_USDT.csv with 972 rows
# ------
# Get 12/660
# File ../binance_data/historical/BINANCE_SPOT_TIA_USDT.csv exists, get last row
# Existing file has 893 rows
# Last date in existing file is 2026-04-11
# File BINANCE_SPOT_TIA_USDT exists, 2nd latest row's date is 2026-04-11
# Get BINANCE_SPOT_TIA_USDT from 2026-04-11 to 2026-04-13
# Fetching BINANCE_SPOT_TIA_USDT from 2026-04-11 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_TIA_USDT.csv with 895 rows
# ------
# Get 13/660
# File ../binance_data/historical/BINANCE_SPOT_LINEA_USDT.csv exists, get last row
# Existing file has 213 rows
# Last date in existing file is 2026-04-11
# File BINANCE_SPOT_LINEA_USDT exists, 2nd latest row's date is 2026-04-11
# Get BINANCE_SPOT_LINEA_USDT from 2026-04-11 to 2026-04-13
# Fetching BINANCE_SPOT_LINEA_USDT from 2026-04-11 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_LINEA_USDT.csv with 215 rows
# ------
# Get 14/660
# File ../binance_data/historical/BINANCE_SPOT_DCR_USDT.csv exists, get last row
# Existing file has 2074 rows
# Last date in existing file is 2026-04-05
# File BINANCE_SPOT_DCR_USDT exists, 2nd latest row's date is 2026-04-05
# Get BINANCE_SPOT_DCR_USDT from 2026-04-05 to 2026-04-13
# Fetching BINANCE_SPOT_DCR_USDT from 2026-04-05 to 2026-04-13 …
# Fetched 8 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_DCR_USDT.csv with 2082 rows
# ------
# Get 15/660
# File ../binance_data/historical/BINANCE_SPOT_API3_USDT.csv exists, get last row
# Existing file has 1540 rows
# Last date in existing file is 2026-04-11
# File BINANCE_SPOT_API3_USDT exists, 2nd latest row's date is 2026-04-11
# Get BINANCE_SPOT_API3_USDT from 2026-04-11 to 2026-04-13
# Fetching BINANCE_SPOT_API3_USDT from 2026-04-11 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_API3_USDT.csv with 1542 rows
# ------
# Get 16/660
# File ../binance_data/historical/BINANCE_SPOT_HIVE_USDT.csv exists, get last row
# Existing file has 2168 rows
# Last date in existing file is 2026-04-05
# File BINANCE_SPOT_HIVE_USDT exists, 2nd latest row's date is 2026-04-05
# Get BINANCE_SPOT_HIVE_USDT from 2026-04-05 to 2026-04-13
# Fetching BINANCE_SPOT_HIVE_USDT from 2026-04-05 to 2026-04-13 …
# Fetched 8 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_HIVE_USDT.csv with 2176 rows
# ------
# Get 17/660
# File ../binance_data/historical/BINANCE_SPOT_DYM_USDT.csv exists, get last row
# Existing file has 795 rows
# Last date in existing file is 2026-04-11
# File BINANCE_SPOT_DYM_USDT exists, 2nd latest row's date is 2026-04-11
# Get BINANCE_SPOT_DYM_USDT from 2026-04-11 to 2026-04-13
# Fetching BINANCE_SPOT_DYM_USDT from 2026-04-11 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_DYM_USDT.csv with 797 rows
# ------
# Get 18/660
# File ../binance_data/historical/BINANCE_SPOT_GUN_USDT.csv exists, get last row
# Existing file has 376 rows
# Last date in existing file is 2026-04-11
# File BINANCE_SPOT_GUN_USDT exists, 2nd latest row's date is 2026-04-11
# Get BINANCE_SPOT_GUN_USDT from 2026-04-11 to 2026-04-13
# Fetching BINANCE_SPOT_GUN_USDT from 2026-04-11 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_GUN_USDT.csv with 378 rows
# ------
# Get 19/660
# File ../binance_data/historical/BINANCE_SPOT_USUAL_USDT.csv exists, get last row
# Existing file has 508 rows
# Last date in existing file is 2026-04-11
# File BINANCE_SPOT_USUAL_USDT exists, 2nd latest row's date is 2026-04-11
# Get BINANCE_SPOT_USUAL_USDT from 2026-04-11 to 2026-04-13
# Fetching BINANCE_SPOT_USUAL_USDT from 2026-04-11 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_USUAL_USDT.csv with 510 rows
# ------
# Get 20/660
# File ../binance_data/historical/BINANCE_SPOT_EOSBULL_USDT.csv exists, get last row
# Existing file has 46 rows
# Last date in existing file is 2020-03-30
# File BINANCE_SPOT_EOSBULL_USDT exists, 2nd latest row's date is 2020-03-30
# Get BINANCE_SPOT_EOSBULL_USDT from 2020-03-30 to 2026-04-13
# Fetching BINANCE_SPOT_EOSBULL_USDT from 2020-03-30 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_EOSBULL_USDT.csv with 48 rows
# ------
# Get 21/660
# File ../binance_data/historical/BINANCE_SPOT_MMT_USDT.csv exists, get last row
# Existing file has 158 rows
# Last date in existing file is 2026-04-11
# File BINANCE_SPOT_MMT_USDT exists, 2nd latest row's date is 2026-04-11
# Get BINANCE_SPOT_MMT_USDT from 2026-04-11 to 2026-04-13
# Fetching BINANCE_SPOT_MMT_USDT from 2026-04-11 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_MMT_USDT.csv with 160 rows
# ------
# Get 22/660
# File ../binance_data/historical/BINANCE_SPOT_LINKUP_USDT.csv exists, get last row
# Existing file has 993 rows
# Last date in existing file is 2023-04-05
# File BINANCE_SPOT_LINKUP_USDT exists, 2nd latest row's date is 2023-04-05
# Get BINANCE_SPOT_LINKUP_USDT from 2023-04-05 to 2026-04-13
# Fetching BINANCE_SPOT_LINKUP_USDT from 2023-04-05 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_LINKUP_USDT.csv with 995 rows
# ------
# Get 23/660
# File ../binance_data/historical/BINANCE_SPOT_BCH_USDT_1D8DB09.csv exists, get last row
# Existing file has 981 rows
# Last date in existing file is 2026-04-11
# File BINANCE_SPOT_BCH_USDT_1D8DB09 exists, 2nd latest row's date is 2026-04-11
# Get BINANCE_SPOT_BCH_USDT_1D8DB09 from 2026-04-11 to 2026-04-13
# Fetching BINANCE_SPOT_BCH_USDT_1D8DB09 from 2026-04-11 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BCH_USDT_1D8DB09.csv with 983 rows
# ------
# Get 24/660
# File ../binance_data/historical/BINANCE_SPOT_BNB_USDT.csv exists, get last row
# Existing file has 3072 rows
# Last date in existing file is 2026-04-05
# File BINANCE_SPOT_BNB_USDT exists, 2nd latest row's date is 2026-04-05
# Get BINANCE_SPOT_BNB_USDT from 2026-04-05 to 2026-04-13
# Fetching BINANCE_SPOT_BNB_USDT from 2026-04-05 to 2026-04-13 …
# Fetched 8 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BNB_USDT.csv with 3080 rows
# ------
# Get 25/660
# File ../binance_data/historical/BINANCE_SPOT_FIS_USDT.csv exists, get last row
# Existing file has 1748 rows
# Last date in existing file is 2025-12-16
# File BINANCE_SPOT_FIS_USDT exists, 2nd latest row's date is 2025-12-16
# Get BINANCE_SPOT_FIS_USDT from 2025-12-16 to 2026-04-13
# Fetching BINANCE_SPOT_FIS_USDT from 2025-12-16 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_FIS_USDT.csv with 1750 rows
# ------
# Get 26/660
# File ../binance_data/historical/BINANCE_SPOT_HOME_USDT.csv exists, get last row
# Existing file has 303 rows
# Last date in existing file is 2026-04-11
# File BINANCE_SPOT_HOME_USDT exists, 2nd latest row's date is 2026-04-11
# Get BINANCE_SPOT_HOME_USDT from 2026-04-11 to 2026-04-13
# Fetching BINANCE_SPOT_HOME_USDT from 2026-04-11 to 2026-04-13 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_HOME_USDT.csv with 305 rows
# ------
# Get 27/660
# File ../binance_data/historical/BINANCE_SPOT_IOTA_USDT.csv exists, get last row
# Existing file has 2866 rows
# Last date in existing file is 2026-04-05
# File BINANCE_SPOT_IOTA_USDT exists, 2nd latest row's date is 2026-04-05
# Get BINANCE_SPOT_IOTA_USDT from 2026-04-05 to 2026-04-13
# Fetching BINANCE_SPOT_IOTA_USDT from 2026-04-05 to 2026-04-13 …
# Fetched 8 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_IOTA_USDT.csv with 2874 rows
# ------
# Get 28/660
# File ../binance_data/historical/BINANCE_SPOT_GMT_USDT.csv exists, get last row
# Existing file has 1487 rows
# Last date in existing file is 2026-04-05
# File BINANCE_SPOT_GMT_USDT exists, 2nd latest row's date is 2026-04-05
# Get BINANCE_SPOT_GMT_USDT from 2026-04-05 to 2026-04-13
# Fetching BINANCE_SPOT_GMT_USDT from 2026-04-05 to 2026-04-13 …
# Fetched 8 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_GMT_USDT.csv with 1495 rows
# ------
# Get 29/660
# File ../binance_data/historical/BINANCE_SPOT_NOM_USDT.csv exists, get last row
# Existing file has 192 rows
# Last date in existing file is 2026-04-11
# File BINANCE_SPOT_NOM_USDT exists, 2nd latest row's date is 2026-04-11
# Get BINANCE_SPOT_NOM_USDT from 2026-04-11 to 2026-04-13
# Fetching BINANCE_SPOT_NOM_USDT from 2026-04-11 to 2026-04-13 …
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[35], line 53
#      51     continue
#      52 print(f'Get {symbol_id} from {start_date} to {end_date}')
# ---> 53 new_content = coinapi_fetcher.get_history(symbol_id, start_date, end_date)
#      54 # Make sure that content was returned before we concat an empty DF (which would fail)
#      55 if (not new_content.empty):
#
# File ~/Documents/Aktien/Code/Python/2025-11-crypto/src/coinapi_fetcher.py:32, in get_history(symbol, start_time, end_time)
#      23 # Fetch until end_time is reached *or* get the next full batch
#      24 # request_end_time = min(end_time, start_time + timedelta(days=days_to_fetch))
#      25 params = {
#      26     'period_id': '1DAY',
#      27     'time_start': start_time.isoformat(),
#    (...)     30     'limit': 100000,
#      31 }
# ---> 32 data = get(f'https://rest.coinapi.io/v1/ohlcv/{symbol}/history', params)
#      33 raw_df = pd.DataFrame(data)
#      34 result = pd.DataFrame()
#
# File <string>:4, in get(url, params)
#
# HTTPError: 503 Service Unavailable: {
#     "message": "503 Service Unavailable - No server is available to handle this request."
# }

# %%
# Turns out: /history returns active *and* delisted data
for symbol_id in active:
    if (symbol_id not in historical):
        print(f'!!!!! Active symbol {symbol_id} not in historical list')
#     file_path = f'{output_folder}/active/{symbol_id}.csv'
#     start_date = get_latest_entry_date(file_path) or first_date
#     end_date = date.today()
#     if (start_date >= end_date):
#         print(f'Skip {symbol_id}, start is on or after end')
#         continue
#     print(f'Get {symbol_id} from {start_date}')
#     data = coinapi_fetcher.get_history(symbol_id, start_date)
#     write_file(data, file_path)
#     time.sleep(1)

# print('Done')
