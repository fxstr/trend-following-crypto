# %% [markdown]
# Why Coinapi?
# - Delisted symbols
# - Long history (back to the origins)
# - Cleaned data
# - Pricing quite fair and usage-based (Coinmarketcap costs $700/month for the same)

# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
from datetime import datetime, date
import os
from matplotlib import pyplot as plt
import coinapi_fetcher
import time
from dotenv import load_dotenv

load_dotenv()

exchange = os.getenv('COINAPI_EXCHANGE')
base_currency = os.getenv('COINAPI_BASE_CURRENCY')

output_folder = f'../{exchange.lower()}_data/'
print(f'Store files in {output_folder}')
# Out:
# Store files in ../binance_data/

# %%
# btc = coinapi_fetcher.get_history('COINBASE_SPOT_BTC_USD', datetime(2010, 1, 1))
# btc['close'].plot(figsize=(15, 6))
# plt.show()
# btc.to_csv(os.path.join(output_folder, 'COINBASE_SPOT_BTC_USD.csv'), index=True)

# %%
# Binance doesn't have base currency USD; use BTC and re-caculate (BINANCE has a market share
# of approx 40%)
# Problem: There is no BTC-BTC, so we don't get the BTC volume. Use Coinbase instead, as they
# directly quote USD.
exchange_id = exchange
active = coinapi_fetcher.get_active_symbols(exchange_id, base_currency=base_currency)
historical = coinapi_fetcher.get_historical_symbols(exchange_id, base_currency=base_currency)

print(f'Got {len(active)} active and {len(historical)} historical symbols')
print(f'Active symbols: {active}.to_list()')
print(f'Historical symbols: {historical}.to_list()')
# Out:
# Get active symbols for BINANCE
# Get historical symbols for BINANCE, adding to 0 existing
# Out of 1000 historical, 183 are USDT-based
# Get historical symbols for BINANCE, adding to 183 existing
# Out of 1000 historical, 189 are USDT-based
# Get historical symbols for BINANCE, adding to 372 existing
# Out of 1000 historical, 176 are USDT-based
# Get historical symbols for BINANCE, adding to 548 existing
# Out of 511 historical, 100 are USDT-based
# Got 644 active and 648 historical symbols
# Active symbols: ['BINANCE_SPOT_STORJ_USDT', 'BINANCE_SPOT_JTO_USDT', 'BINANCE_SPOT_STPT_USDT', 'BINANCE_SPOT_ALGO_USDT', 'BINANCE_SPOT_LISTA_USDT', 'BINANCE_SPOT_PDA_USDT', 'BINANCE_SPOT_TIA_USDT', 'BINANCE_SPOT_WAXP_USDT', 'BINANCE_SPOT_PORTAL_USDT', 'BINANCE_SPOT_BURGER_USDT', 'BINANCE_SPOT_AMB_USDT', 'BINANCE_SPOT_NU_USDT', 'BINANCE_SPOT_QUICK_USDT', 'BINANCE_SPOT_RIF_USDT', 'BINANCE_SPOT_FTT_USDT', 'BINANCE_SPOT_TRXDOWN_USDT', 'BINANCE_SPOT_DEGO_USDT', 'BINANCE_SPOT_1000CHEEMS_USDT', 'BINANCE_SPOT_LRC_USDT', 'BINANCE_SPOT_ANKR_USDT', 'BINANCE_SPOT_ASR_USDT', 'BINANCE_SPOT_SANTOS_USDT', 'BINANCE_SPOT_BLZ_USDT', 'BINANCE_SPOT_ERA_USDT', 'BINANCE_SPOT_CVX_USDT', 'BINANCE_SPOT_1INCHUP_USDT', 'BINANCE_SPOT_ETHBEAR_USDT', 'BINANCE_SPOT_BTCDOWN_USDT', 'BINANCE_SPOT_SAND_USDT', 'BINANCE_SPOT_REP_USDT', 'BINANCE_SPOT_KNC_USDT', 'BINANCE_SPOT_JOE_USDT', 'BINANCE_SPOT_FRONT_USDT', 'BINANCE_SPOT_WIF_USDT', 'BINANCE_SPOT_MIR_USDT', 'BINANCE_SPOT_OOKI_USDT', 'BINANCE_SPOT_PROS_USDT', 'BINANCE_SPOT_STO_USDT', 'BINANCE_SPOT_IDEX_USDT', 'BINANCE_SPOT_ASTR_USDT', 'BINANCE_SPOT_IQ_USDT', 'BINANCE_SPOT_PHA_USDT', 'BINANCE_SPOT_NOM_USDT', 'BINANCE_SPOT_SPELL_USDT', 'BINANCE_SPOT_ANY_USDT', 'BINANCE_SPOT_ANC_USDT', 'BINANCE_SPOT_ENA_USDT', 'BINANCE_SPOT_SUSHIDOWN_USDT', 'BINANCE_SPOT_MAGIC_USDT', 'BINANCE_SPOT_DOTUP_USDT', 'BINANCE_SPOT_KLAY_USDT', 'BINANCE_SPOT_WAVES_USDT', 'BINANCE_SPOT_BERA_USDT', 'BINANCE_SPOT_TRU_USDT', 'BINANCE_SPOT_ZRX_USDT', 'BINANCE_SPOT_FIRO_USDT', 'BINANCE_SPOT_LOOM_USDT', 'BINANCE_SPOT_STRK_USDT', 'BINANCE_SPOT_S_USDT', 'BINANCE_SPOT_T_USDT', 'BINANCE_SPOT_U_USDT', 'BINANCE_SPOT_W_USDT', 'BINANCE_SPOT_AUDIO_USDT', 'BINANCE_SPOT_A_USDT', 'BINANCE_SPOT_C_USDT', 'BINANCE_SPOT_D_USDT', 'BINANCE_SPOT_F_USDT', 'BINANCE_SPOT_INJ_USDT', 'BINANCE_SPOT_G_USDT', 'BINANCE_SPOT_AUTO_USDT', 'BINANCE_SPOT_RED_USDT', 'BINANCE_SPOT_DIA_USDT', 'BINANCE_SPOT_TRB_USDT', 'BINANCE_SPOT_ADADOWN_USDT', 'BINANCE_SPOT_LTO_USDT', 'BINANCE_SPOT_RONIN_USDT', 'BINANCE_SPOT_GMX_USDT', 'BINANCE_SPOT_USD1_USDT', 'BINANCE_SPOT_GIGGLE_USDT', 'BINANCE_SPOT_ALPACA_USDT', 'BINANCE_SPOT_KDA_USDT', 'BINANCE_SPOT_BAND_USDT', 'BINANCE_SPOT_BNBUP_USDT', 'BINANCE_SPOT_AWE_USDT', 'BINANCE_SPOT_ZEN_USDT', 'BINANCE_SPOT_SCROLL_USDT', 'BINANCE_SPOT_VIB_USDT', 'BINANCE_SPOT_PLUME_USDT', 'BINANCE_SPOT_PEOPLE_USDT', 'BINANCE_SPOT_MMT_USDT', 'BINANCE_SPOT_DODO_USDT', 'BINANCE_SPOT_SXPDOWN_USDT', 'BINANCE_SPOT_EPX_USDT', 'BINANCE_SPOT_BTCST_USDT', 'BINANCE_SPOT_YFI_USDT', 'BINANCE_SPOT_SNX_USDT', 'BINANCE_SPOT_BMT_USDT', 'BINANCE_SPOT_AERGO_USDT', 'BINANCE_SPOT_MEME_USDT', 'BINANCE_SPOT_SAHARA_USDT', 'BINANCE_SPOT_ENJ_USDT', 'BINANCE_SPOT_CHR_USDT', 'BINANCE_SPOT_BEL_USDT', 'BINANCE_SPOT_PORTO_USDT', 'BINANCE_SPOT_WRX_USDT', 'BINANCE_SPOT_ARDR_USDT', 'BINANCE_SPOT_LUNA_USDT', 'BINANCE_SPOT_ADA_USDT', 'BINANCE_SPOT_1000SATS_USDT', 'BINANCE_SPOT_SOL_USDT', 'BINANCE_SPOT_ETHDOWN_USDT', 'BINANCE_SPOT_TRX_USDT', 'BINANCE_SPOT_POL_USDT', 'BINANCE_SPOT_REN_USDT', 'BINANCE_SPOT_ARB_USDT', 'BINANCE_SPOT_EIGEN_USDT', 'BINANCE_SPOT_FDUSD_USDT', 'BINANCE_SPOT_DF_USDT', 'BINANCE_SPOT_FF_USDT', 'BINANCE_SPOT_COOKIE_USDT', 'BINANCE_SPOT_THETA_USDT', 'BINANCE_SPOT_SUPER_USDT', 'BINANCE_SPOT_MUBARAK_USDT', 'BINANCE_SPOT_FRAX_USDT', 'BINANCE_SPOT_ZKC_USDT', 'BINANCE_SPOT_GTO_USDT', 'BINANCE_SPOT_DYM_USDT', 'BINANCE_SPOT_PYTH_USDT', 'BINANCE_SPOT_ONDO_USDT', 'BINANCE_SPOT_BEAMX_USDT', 'BINANCE_SPOT_BNB_USDT', 'BINANCE_SPOT_EOSDOWN_USDT', 'BINANCE_SPOT_VEN_USDT', 'BINANCE_SPOT_NKN_USDT', 'BINANCE_SPOT_FOGO_USDT', 'BINANCE_SPOT_ALPHA_USDT', 'BINANCE_SPOT_LPT_USDT', 'BINANCE_SPOT_C98_USDT', 'BINANCE_SPOT_PHB_USDT', 'BINANCE_SPOT_ID_USDT', 'BINANCE_SPOT_GMT_USDT', 'BINANCE_SPOT_RDNT_USDT', 'BINANCE_SPOT_PROM_USDT', 'BINANCE_SPOT_APT_USDT', 'BINANCE_SPOT_VITE_USDT', 'BINANCE_SPOT_RUNE_USDT', 'BINANCE_SPOT_ORDI_USDT', 'BINANCE_SPOT_NEWT_USDT', 'BINANCE_SPOT_KAITO_USDT', 'BINANCE_SPOT_MATIC_USDT', 'BINANCE_SPOT_USDS_USDT', 'BINANCE_SPOT_CYBER_USDT', 'BINANCE_SPOT_PEPE_USDT', 'BINANCE_SPOT_SYS_ ...
# Historical symbols: ['BINANCE_SPOT_BCC_USDT', 'BINANCE_SPOT_BNB_USDT', 'BINANCE_SPOT_BTC_USDT', 'BINANCE_SPOT_ADA_USDT', 'BINANCE_SPOT_BCHSV_USDT', 'BINANCE_SPOT_BTT_USDT', 'BINANCE_SPOT_BAT_USDT', 'BINANCE_SPOT_CELR_USDT', 'BINANCE_SPOT_DASH_USDT', 'BINANCE_SPOT_ATOM_USDT', 'BINANCE_SPOT_ALGO_USDT', 'BINANCE_SPOT_DOGE_USDT', 'BINANCE_SPOT_ANKR_USDT', 'BINANCE_SPOT_COS_USDT', 'BINANCE_SPOT_COCOS_USDT', 'BINANCE_SPOT_CVC_USDT', 'BINANCE_SPOT_DOCK_USDT', 'BINANCE_SPOT_DENT_USDT', 'BINANCE_SPOT_CHZ_USDT', 'BINANCE_SPOT_BAND_USDT', 'BINANCE_SPOT_BUSD_USDT', 'BINANCE_SPOT_BEAM_USDT', 'BINANCE_SPOT_ARPA_USDT', 'BINANCE_SPOT_CTXC_USDT', 'BINANCE_SPOT_BULL_USDT', 'BINANCE_SPOT_BEAR_USDT', 'BINANCE_SPOT_BNT_USDT', 'BINANCE_SPOT_BTS_USDT', 'BINANCE_SPOT_AION_USDT', 'BINANCE_SPOT_COTI_USDT', 'BINANCE_SPOT_BNBBULL_USDT', 'BINANCE_SPOT_BNBBEAR_USDT', 'BINANCE_SPOT_DATA_USDT', 'BINANCE_SPOT_CTSI_USDT', 'BINANCE_SPOT_CHR_USDT', 'BINANCE_SPOT_BTCUP_USDT', 'BINANCE_SPOT_BTCDOWN_USDT', 'BINANCE_SPOT_ARDR_USDT', 'BINANCE_SPOT_COMP_USDT', 'BINANCE_SPOT_BKRW_USDT', 'BINANCE_SPOT_ADAUP_USDT', 'BINANCE_SPOT_ADADOWN_USDT', 'BINANCE_SPOT_DGB_USDT', 'BINANCE_SPOT_DAI_USDT', 'BINANCE_SPOT_DCR_USDT', 'BINANCE_SPOT_BNBUP_USDT', 'BINANCE_SPOT_BNBDOWN_USDT', 'BINANCE_SPOT_AUD_USDT', 'BINANCE_SPOT_BLZ_USDT', 'BINANCE_SPOT_BAL_USDT', 'BINANCE_SPOT_ANT_USDT', 'BINANCE_SPOT_CRV_USDT', 'BINANCE_SPOT_BZRX_USDT', 'BINANCE_SPOT_DIA_USDT', 'BINANCE_SPOT_BEL_USDT', 'BINANCE_SPOT_AVAX_USDT', 'BINANCE_SPOT_ALPHA_USDT', 'BINANCE_SPOT_AAVE_USDT', 'BINANCE_SPOT_AUDIO_USDT', 'BINANCE_SPOT_CTK_USDT', 'BINANCE_SPOT_BCHUP_USDT', 'BINANCE_SPOT_BCHDOWN_USDT', 'BINANCE_SPOT_AKRO_USDT', 'BINANCE_SPOT_AXS_USDT', 'BINANCE_SPOT_DNT_USDT', 'BINANCE_SPOT_AVA_USDT', 'BINANCE_SPOT_AAVEUP_USDT', 'BINANCE_SPOT_AAVEDOWN_USDT', 'BINANCE_SPOT_1INCH_USDT', 'BINANCE_SPOT_ATM_USDT', 'BINANCE_SPOT_ASR_USDT', 'BINANCE_SPOT_CELO_USDT', 'BINANCE_SPOT_BTCST_USDT', 'BINANCE_SPOT_CKB_USDT', 'BINANCE_SPOT_CAKE_USDT', 'BINANCE_SPOT_DODO_USDT', 'BINANCE_SPOT_ACM_USDT', 'BINANCE_SPOT_BADGER_USDT', 'BINANCE_SPOT_DEGO_USDT', 'BINANCE_SPOT_ALICE_USDT', 'BINANCE_SPOT_CFX_USDT', 'BINANCE_SPOT_AUTO_USDT', 'BINANCE_SPOT_1INCHUP_USDT', 'BINANCE_SPOT_1INCHDOWN_USDT', 'BINANCE_SPOT_BTG_USDT', 'BINANCE_SPOT_BAR_USDT', 'BINANCE_SPOT_BAKE_USDT', 'BINANCE_SPOT_BURGER_USDT', 'BINANCE_SPOT_AR_USDT', 'BINANCE_SPOT_ATA_USDT', 'BINANCE_SPOT_BOND_USDT', 'BINANCE_SPOT_DEXE_USDT', 'BINANCE_SPOT_C98_USDT', 'BINANCE_SPOT_CLV_USDT', 'BINANCE_SPOT_ALPACA_USDT', 'BINANCE_SPOT_DF_USDT', 'BINANCE_SPOT_CVP_USDT', 'BINANCE_SPOT_AGLD_USDT', 'BINANCE_SPOT_BETA_USDT', 'BINANCE_SPOT_CHESS_USDT', 'BINANCE_SPOT_ADX_USDT', 'BINANCE_SPOT_AUCTION_USDT', 'BINANCE_SPOT_DAR_USDT', 'BINANCE_SPOT_BNX_USDT', 'BINANCE_SPOT_CITY_USDT', 'BINANCE_SPOT_AMP_USDT', 'BINANCE_SPOT_ALCX_USDT', 'BINANCE_SPOT_ANY_USDT', 'BINANCE_SPOT_BICO_USDT', 'BINANCE_SPOT_CVX_USDT', 'BINANCE_SPOT_ACH_USDT', 'BINANCE_SPOT_API3_USDT', 'BINANCE_SPOT_BTTC_USDT', 'BINANCE_SPOT_ANC_USDT', 'BINANCE_SPOT_ACA_USDT', 'BINANCE_SPOT_ALPINE_USDT', 'BINANCE_SPOT_ASTR_USDT', 'BINANCE_SPOT_APE_USDT', 'BINANCE_SPOT_BSW_USDT', 'BINANCE_SPOT_BIFI_USDT', 'BINANCE_SPOT_APT_USDT', 'BINANCE_SPOT_AGIX_USDT', 'BINANCE_SPOT_BETH_USDT', 'BINANCE_SPOT_AMB_USDT', 'BINANCE_SPOT_ARB_USDT', 'BINANCE_SPOT_AERGO_USDT', 'BINANCE_SPOT_AST_USDT', 'BINANCE_SPOT_COMBO_USDT', 'BINANCE_SPOT_ARKM_USDT', 'BINANCE_SPOT_CYBER_USDT', 'BINANCE_SPOT_BCH_USDT_1D8DB09', 'BINANCE_SPOT_BCH_USDT_1DAF325', 'BINANCE_SPOT_ARK_USDT', 'BINANCE_SPOT_CREAM_USDT', 'BINANCE_SPOT_BEAMX_USDT', 'BINANCE_SPOT_BLUR_USDT', 'BINANCE_SPOT_AEUR_USDT', 'BINANCE_SPOT_1000SATS_USDT', 'BINANCE_SPOT_BONK_USDT', 'BINANCE_SPOT_ACE_USDT', 'BINANCE_SPOT_AI_USDT', 'BINANCE_SPOT_ALT_USDT', 'BINANCE_SPOT_AXL_USDT', 'BINANCE_SPOT_AEVO_USDT', 'BINANCE_SPOT_BOME_USDT', 'BINANCE_SPOT_BB_USDT', 'BINANCE_SPOT_BANANA_USDT', 'BINANCE_SPOT_DOGS_USDT', 'BINANCE_SPOT_1MBABYDOGE_USDT', 'BINANCE_SPOT_CATI_USDT', 'BINANCE_SPOT_BNSOL_USDT', 'BINANCE_SPOT_COW_USDT', 'BINA ...

# %%
def write_file(data, file_path):
    data.to_csv(file_path, index=True)
    print(f'Wrote file {file_path} with {len(data)} rows')

def get_existing_content(file_path):
    '''
    Returns the date of the last row in the file, if it exists, and its whole content (which
    is needed to append new data to later).
    '''
    if os.path.exists(file_path):
        print(f'File {file_path} exists, get last row')
        content = pd.read_csv(file_path)
        # When the file is empty, there's no 'date' column that we can use as index; return an
        # empty df so that all data is fetched from the crypto's start of existence.
        if ('date' not in content.columns):
            print('File is missing date column, return empty DataFrame')
            return (pd.DataFrame(), None)
        # Remove the last row; it may contain intraday data; make it 2 to be sure.
        content = content.iloc[:-2]
        content['date'] = pd.to_datetime(content['date'])
        content.set_index('date', inplace=True)
        print(f'Existing file has {len(content)} rows')
        if(len(content)):
            last_date = content.index[-1].date()
            print(f'Last date in existing file is {last_date}')
            return (content, last_date)
        return (content, None)
    else:
        return (pd.DataFrame(), None)

first_date = date(2010, 1, 1)

current_index = 0
# Historical contains *all* cryptos, delisted as well as active. Delisted ones just won't return
# any new data.
for symbol_id in historical:
    current_index += 1
    print('------')
    print(f'Get {current_index}/{len(historical)}')
    file_path = os.path.join(output_folder, 'historical', f'{symbol_id}.csv')
    (existing_content, start_date) = get_existing_content(file_path)
    if (start_date):
        print(f'File {symbol_id} exists, 2nd latest row\'s date is {start_date}')
    else:
        start_date = first_date
        print(f'File {symbol_id} does not exist')
    end_date = date.today()
    if (start_date >= end_date):
        print(f'Skip {symbol_id}, start is on or after end')
        continue
    print(f'Get {symbol_id} from {start_date} to {end_date}')
    new_content = coinapi_fetcher.get_history(symbol_id, start_date, end_date)
    # Make sure that content was returned before we concat an empty DF (which would fail)
    if (not new_content.empty):
        data = pd.concat([df for df in [existing_content, new_content] if not df.empty])
        write_file(data, file_path)
    time.sleep(0.5)
print(f'Out of {len(historical)} cryptos, {current_index} were fetched')
# Out:
# ------
# Get 1/648
# File ../binance_data/historical/BINANCE_SPOT_BCC_USDT.csv exists, get last row
# Existing file has 2045 rows
# Last date in existing file is 2023-08-28
# File BINANCE_SPOT_BCC_USDT exists, 2nd latest row's date is 2023-08-28
# Get BINANCE_SPOT_BCC_USDT from 2023-08-28 to 2026-01-26
# Fetching BINANCE_SPOT_BCC_USDT from 2023-08-28 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BCC_USDT.csv with 2047 rows
# ------
# Get 2/648
# File ../binance_data/historical/BINANCE_SPOT_BNB_USDT.csv exists, get last row
# Existing file has 2996 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_BNB_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_BNB_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_BNB_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BNB_USDT.csv with 3002 rows
# ------
# Get 3/648
# File ../binance_data/historical/BINANCE_SPOT_BTC_USDT.csv exists, get last row
# Existing file has 3077 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_BTC_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_BTC_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_BTC_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BTC_USDT.csv with 3083 rows
# ------
# Get 4/648
# File ../binance_data/historical/BINANCE_SPOT_ADA_USDT.csv exists, get last row
# Existing file has 2834 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_ADA_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_ADA_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_ADA_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ADA_USDT.csv with 2840 rows
# ------
# Get 5/648
# File ../binance_data/historical/BINANCE_SPOT_BCHSV_USDT.csv exists, get last row
# Existing file has 152 rows
# Last date in existing file is 2019-04-21
# File BINANCE_SPOT_BCHSV_USDT exists, 2nd latest row's date is 2019-04-21
# Get BINANCE_SPOT_BCHSV_USDT from 2019-04-21 to 2026-01-26
# Fetching BINANCE_SPOT_BCHSV_USDT from 2019-04-21 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BCHSV_USDT.csv with 154 rows
# ------
# Get 6/648
# File ../binance_data/historical/BINANCE_SPOT_BTT_USDT.csv exists, get last row
# Existing file has 1075 rows
# Last date in existing file is 2022-01-16
# File BINANCE_SPOT_BTT_USDT exists, 2nd latest row's date is 2022-01-16
# Get BINANCE_SPOT_BTT_USDT from 2022-01-16 to 2026-01-26
# Fetching BINANCE_SPOT_BTT_USDT from 2022-01-16 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BTT_USDT.csv with 1077 rows
# ------
# Get 7/648
# File ../binance_data/historical/BINANCE_SPOT_BAT_USDT.csv exists, get last row
# Existing file has 2504 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_BAT_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_BAT_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_BAT_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BAT_USDT.csv with 2510 rows
# ------
# Get 8/648
# File ../binance_data/historical/BINANCE_SPOT_CELR_USDT.csv exists, get last row
# Existing file has 2483 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_CELR_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_CELR_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_CELR_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_CELR_USDT.csv with 2489 rows
# ------
# Get 9/648
# File ../binance_data/historical/BINANCE_SPOT_DASH_USDT.csv exists, get last row
# Existing file has 2483 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_DASH_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_DASH_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_DASH_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_DASH_USDT.csv with 2489 rows
# ------
# Get 10/648
# File ../binance_data/historical/BINANCE_SPOT_ATOM_USDT.csv exists, get last row
# Existing file has 2455 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_ATOM_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_ATOM_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_ATOM_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ATOM_USDT.csv with 2461 rows
# ------
# Get 11/648
# File ../binance_data/historical/BINANCE_SPOT_ALGO_USDT.csv exists, get last row
# Existing file has 2402 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_ALGO_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_ALGO_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_ALGO_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ALGO_USDT.csv with 2408 rows
# ------
# Get 12/648
# File ../binance_data/historical/BINANCE_SPOT_DOGE_USDT.csv exists, get last row
# Existing file has 2383 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_DOGE_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_DOGE_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_DOGE_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_DOGE_USDT.csv with 2389 rows
# ------
# Get 13/648
# File ../binance_data/historical/BINANCE_SPOT_ANKR_USDT.csv exists, get last row
# Existing file has 2365 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_ANKR_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_ANKR_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_ANKR_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ANKR_USDT.csv with 2371 rows
# ------
# Get 14/648
# File ../binance_data/historical/BINANCE_SPOT_COS_USDT.csv exists, get last row
# Existing file has 2355 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_COS_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_COS_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_COS_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_COS_USDT.csv with 2361 rows
# ------
# Get 15/648
# File ../binance_data/historical/BINANCE_SPOT_COCOS_USDT.csv exists, get last row
# Existing file has 1362 rows
# Last date in existing file is 2023-05-28
# File BINANCE_SPOT_COCOS_USDT exists, 2nd latest row's date is 2023-05-28
# Get BINANCE_SPOT_COCOS_USDT from 2023-05-28 to 2026-01-26
# Fetching BINANCE_SPOT_COCOS_USDT from 2023-05-28 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_COCOS_USDT.csv with 1364 rows
# ------
# Get 16/648
# File ../binance_data/historical/BINANCE_SPOT_CVC_USDT.csv exists, get last row
# Existing file has 2176 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_CVC_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_CVC_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_CVC_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_CVC_USDT.csv with 2182 rows
# ------
# Get 17/648
# File ../binance_data/historical/BINANCE_SPOT_DOCK_USDT.csv exists, get last row
# Existing file has 1782 rows
# Last date in existing file is 2024-07-21
# File BINANCE_SPOT_DOCK_USDT exists, 2nd latest row's date is 2024-07-21
# Get BINANCE_SPOT_DOCK_USDT from 2024-07-21 to 2026-01-26
# Fetching BINANCE_SPOT_DOCK_USDT from 2024-07-21 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_DOCK_USDT.csv with 1784 rows
# ------
# Get 18/648
# File ../binance_data/historical/BINANCE_SPOT_DENT_USDT.csv exists, get last row
# Existing file has 2331 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_DENT_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_DENT_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_DENT_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_DENT_USDT.csv with 2337 rows
# ------
# Get 19/648
# File ../binance_data/historical/BINANCE_SPOT_CHZ_USDT.csv exists, get last row
# Existing file has 2320 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_CHZ_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_CHZ_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_CHZ_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_CHZ_USDT.csv with 2326 rows
# ------
# Get 20/648
# File ../binance_data/historical/BINANCE_SPOT_BAND_USDT.csv exists, get last row
# Existing file has 2307 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_BAND_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_BAND_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_BAND_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BAND_USDT.csv with 2313 rows
# ------
# Get 21/648
# File ../binance_data/historical/BINANCE_SPOT_BUSD_USDT.csv exists, get last row
# Existing file has 1539 rows
# Last date in existing file is 2023-12-14
# File BINANCE_SPOT_BUSD_USDT exists, 2nd latest row's date is 2023-12-14
# Get BINANCE_SPOT_BUSD_USDT from 2023-12-14 to 2026-01-26
# Fetching BINANCE_SPOT_BUSD_USDT from 2023-12-14 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BUSD_USDT.csv with 1541 rows
# ------
# Get 22/648
# File ../binance_data/historical/BINANCE_SPOT_BEAM_USDT.csv exists, get last row
# Existing file has 1215 rows
# Last date in existing file is 2023-01-25
# File BINANCE_SPOT_BEAM_USDT exists, 2nd latest row's date is 2023-01-25
# Get BINANCE_SPOT_BEAM_USDT from 2023-01-25 to 2026-01-26
# Fetching BINANCE_SPOT_BEAM_USDT from 2023-01-25 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BEAM_USDT.csv with 1217 rows
# ------
# Get 23/648
# File ../binance_data/historical/BINANCE_SPOT_ARPA_USDT.csv exists, get last row
# Existing file has 2257 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_ARPA_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_ARPA_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_ARPA_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ARPA_USDT.csv with 2263 rows
# ------
# Get 24/648
# File ../binance_data/historical/BINANCE_SPOT_CTXC_USDT.csv exists, get last row
# Existing file has 1962 rows
# Last date in existing file is 2025-04-15
# File BINANCE_SPOT_CTXC_USDT exists, 2nd latest row's date is 2025-04-15
# Get BINANCE_SPOT_CTXC_USDT from 2025-04-15 to 2026-01-26
# Fetching BINANCE_SPOT_CTXC_USDT from 2025-04-15 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_CTXC_USDT.csv with 1964 rows
# ------
# Get 25/648
# File ../binance_data/historical/BINANCE_SPOT_BULL_USDT.csv exists, get last row
# Existing file has 73 rows
# Last date in existing file is 2020-03-30
# File BINANCE_SPOT_BULL_USDT exists, 2nd latest row's date is 2020-03-30
# Get BINANCE_SPOT_BULL_USDT from 2020-03-30 to 2026-01-26
# Fetching BINANCE_SPOT_BULL_USDT from 2020-03-30 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BULL_USDT.csv with 75 rows
# ------
# Get 26/648
# File ../binance_data/historical/BINANCE_SPOT_BEAR_USDT.csv exists, get last row
# Existing file has 73 rows
# Last date in existing file is 2020-03-30
# File BINANCE_SPOT_BEAR_USDT exists, 2nd latest row's date is 2020-03-30
# Get BINANCE_SPOT_BEAR_USDT from 2020-03-30 to 2026-01-26
# Fetching BINANCE_SPOT_BEAR_USDT from 2020-03-30 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BEAR_USDT.csv with 75 rows
# ------
# Get 27/648
# File ../binance_data/historical/BINANCE_SPOT_BNT_USDT.csv exists, get last row
# Existing file has 2166 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_BNT_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_BNT_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_BNT_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BNT_USDT.csv with 2172 rows
# ------
# Get 28/648
# File ../binance_data/historical/BINANCE_SPOT_BTS_USDT.csv exists, get last row
# Existing file has 1391 rows
# Last date in existing file is 2023-12-06
# File BINANCE_SPOT_BTS_USDT exists, 2nd latest row's date is 2023-12-06
# Get BINANCE_SPOT_BTS_USDT from 2023-12-06 to 2026-01-26
# Fetching BINANCE_SPOT_BTS_USDT from 2023-12-06 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BTS_USDT.csv with 1393 rows
# ------
# Get 29/648
# File ../binance_data/historical/BINANCE_SPOT_AION_USDT.csv exists, get last row
# Existing file has 1096 rows
# Last date in existing file is 2023-02-26
# File BINANCE_SPOT_AION_USDT exists, 2nd latest row's date is 2023-02-26
# Get BINANCE_SPOT_AION_USDT from 2023-02-26 to 2026-01-26
# Fetching BINANCE_SPOT_AION_USDT from 2023-02-26 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_AION_USDT.csv with 1098 rows
# ------
# Get 30/648
# File ../binance_data/historical/BINANCE_SPOT_COTI_USDT.csv exists, get last row
# Existing file has 2147 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_COTI_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_COTI_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_COTI_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_COTI_USDT.csv with 2153 rows
# ------
# Get 31/648
# File ../binance_data/historical/BINANCE_SPOT_BNBBULL_USDT.csv exists, get last row
# Existing file has 19 rows
# Last date in existing file is 2020-03-30
# File BINANCE_SPOT_BNBBULL_USDT exists, 2nd latest row's date is 2020-03-30
# Get BINANCE_SPOT_BNBBULL_USDT from 2020-03-30 to 2026-01-26
# Fetching BINANCE_SPOT_BNBBULL_USDT from 2020-03-30 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BNBBULL_USDT.csv with 21 rows
# ------
# Get 32/648
# File ../binance_data/historical/BINANCE_SPOT_BNBBEAR_USDT.csv exists, get last row
# Existing file has 19 rows
# Last date in existing file is 2020-03-30
# File BINANCE_SPOT_BNBBEAR_USDT exists, 2nd latest row's date is 2020-03-30
# Get BINANCE_SPOT_BNBBEAR_USDT from 2020-03-30 to 2026-01-26
# Fetching BINANCE_SPOT_BNBBEAR_USDT from 2020-03-30 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BNBBEAR_USDT.csv with 21 rows
# ------
# Get 33/648
# File ../binance_data/historical/BINANCE_SPOT_DATA_USDT.csv exists, get last row
# Existing file has 2107 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_DATA_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_DATA_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_DATA_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_DATA_USDT.csv with 2113 rows
# ------
# Get 34/648
# File ../binance_data/historical/BINANCE_SPOT_CTSI_USDT.csv exists, get last row
# Existing file has 2091 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_CTSI_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_CTSI_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_CTSI_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_CTSI_USDT.csv with 2097 rows
# ------
# Get 35/648
# File ../binance_data/historical/BINANCE_SPOT_CHR_USDT.csv exists, get last row
# Existing file has 2077 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_CHR_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_CHR_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_CHR_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_CHR_USDT.csv with 2083 rows
# ------
# Get 36/648
# File ../binance_data/historical/BINANCE_SPOT_BTCUP_USDT.csv exists, get last row
# Existing file has 1376 rows
# Last date in existing file is 2024-02-27
# File BINANCE_SPOT_BTCUP_USDT exists, 2nd latest row's date is 2024-02-27
# Get BINANCE_SPOT_BTCUP_USDT from 2024-02-27 to 2026-01-26
# Fetching BINANCE_SPOT_BTCUP_USDT from 2024-02-27 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BTCUP_USDT.csv with 1378 rows
# ------
# Get 37/648
# File ../binance_data/historical/BINANCE_SPOT_BTCDOWN_USDT.csv exists, get last row
# Existing file has 1376 rows
# Last date in existing file is 2024-02-27
# File BINANCE_SPOT_BTCDOWN_USDT exists, 2nd latest row's date is 2024-02-27
# Get BINANCE_SPOT_BTCDOWN_USDT from 2024-02-27 to 2026-01-26
# Fetching BINANCE_SPOT_BTCDOWN_USDT from 2024-02-27 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BTCDOWN_USDT.csv with 1378 rows
# ------
# Get 38/648
# File ../binance_data/historical/BINANCE_SPOT_ARDR_USDT.csv exists, get last row
# Existing file has 2068 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_ARDR_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_ARDR_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_ARDR_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ARDR_USDT.csv with 2074 rows
# ------
# Get 39/648
# File ../binance_data/historical/BINANCE_SPOT_COMP_USDT.csv exists, get last row
# Existing file has 2027 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_COMP_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_COMP_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_COMP_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_COMP_USDT.csv with 2033 rows
# ------
# Get 40/648
# File ../binance_data/historical/BINANCE_SPOT_BKRW_USDT.csv exists, get last row
# Existing file has 31 rows
# Last date in existing file is 2020-08-06
# File BINANCE_SPOT_BKRW_USDT exists, 2nd latest row's date is 2020-08-06
# Get BINANCE_SPOT_BKRW_USDT from 2020-08-06 to 2026-01-26
# Fetching BINANCE_SPOT_BKRW_USDT from 2020-08-06 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BKRW_USDT.csv with 33 rows
# ------
# Get 41/648
# File ../binance_data/historical/BINANCE_SPOT_ADAUP_USDT.csv exists, get last row
# Existing file has 1116 rows
# Last date in existing file is 2023-08-15
# File BINANCE_SPOT_ADAUP_USDT exists, 2nd latest row's date is 2023-08-15
# Get BINANCE_SPOT_ADAUP_USDT from 2023-08-15 to 2026-01-26
# Fetching BINANCE_SPOT_ADAUP_USDT from 2023-08-15 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ADAUP_USDT.csv with 1118 rows
# ------
# Get 42/648
# File ../binance_data/historical/BINANCE_SPOT_ADADOWN_USDT.csv exists, get last row
# Existing file has 1118 rows
# Last date in existing file is 2023-08-15
# File BINANCE_SPOT_ADADOWN_USDT exists, 2nd latest row's date is 2023-08-15
# Get BINANCE_SPOT_ADADOWN_USDT from 2023-08-15 to 2026-01-26
# Fetching BINANCE_SPOT_ADADOWN_USDT from 2023-08-15 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ADADOWN_USDT.csv with 1120 rows
# ------
# Get 43/648
# File ../binance_data/historical/BINANCE_SPOT_DGB_USDT.csv exists, get last row
# Existing file has 2002 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_DGB_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_DGB_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_DGB_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_DGB_USDT.csv with 2008 rows
# ------
# Get 44/648
# File ../binance_data/historical/BINANCE_SPOT_DAI_USDT.csv exists, get last row
# Existing file has 19 rows
# Last date in existing file is 2020-08-11
# File BINANCE_SPOT_DAI_USDT exists, 2nd latest row's date is 2020-08-11
# Get BINANCE_SPOT_DAI_USDT from 2020-08-11 to 2026-01-26
# Fetching BINANCE_SPOT_DAI_USDT from 2020-08-11 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_DAI_USDT.csv with 21 rows
# ------
# Get 45/648
# File ../binance_data/historical/BINANCE_SPOT_DCR_USDT.csv exists, get last row
# Existing file has 1993 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_DCR_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_DCR_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_DCR_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_DCR_USDT.csv with 1999 rows
# ------
# Get 46/648
# File ../binance_data/historical/BINANCE_SPOT_BNBUP_USDT.csv exists, get last row
# Existing file has 1291 rows
# Last date in existing file is 2024-02-27
# File BINANCE_SPOT_BNBUP_USDT exists, 2nd latest row's date is 2024-02-27
# Get BINANCE_SPOT_BNBUP_USDT from 2024-02-27 to 2026-01-26
# Fetching BINANCE_SPOT_BNBUP_USDT from 2024-02-27 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BNBUP_USDT.csv with 1293 rows
# ------
# Get 47/648
# File ../binance_data/historical/BINANCE_SPOT_BNBDOWN_USDT.csv exists, get last row
# Existing file has 1291 rows
# Last date in existing file is 2024-02-27
# File BINANCE_SPOT_BNBDOWN_USDT exists, 2nd latest row's date is 2024-02-27
# Get BINANCE_SPOT_BNBDOWN_USDT from 2024-02-27 to 2026-01-26
# Fetching BINANCE_SPOT_BNBDOWN_USDT from 2024-02-27 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BNBDOWN_USDT.csv with 1293 rows
# ------
# Get 48/648
# File ../binance_data/historical/BINANCE_SPOT_AUD_USDT.csv exists, get last row
# Existing file has 1021 rows
# Last date in existing file is 2023-05-31
# File BINANCE_SPOT_AUD_USDT exists, 2nd latest row's date is 2023-05-31
# Get BINANCE_SPOT_AUD_USDT from 2023-05-31 to 2026-01-26
# Fetching BINANCE_SPOT_AUD_USDT from 2023-05-31 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_AUD_USDT.csv with 1023 rows
# ------
# Get 49/648
# File ../binance_data/historical/BINANCE_SPOT_BLZ_USDT.csv exists, get last row
# Existing file has 1588 rows
# Last date in existing file is 2024-12-24
# File BINANCE_SPOT_BLZ_USDT exists, 2nd latest row's date is 2024-12-24
# Get BINANCE_SPOT_BLZ_USDT from 2024-12-24 to 2026-01-26
# Fetching BINANCE_SPOT_BLZ_USDT from 2024-12-24 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BLZ_USDT.csv with 1590 rows
# ------
# Get 50/648
# File ../binance_data/historical/BINANCE_SPOT_BAL_USDT.csv exists, get last row
# Existing file has 1700 rows
# Last date in existing file is 2025-04-15
# File BINANCE_SPOT_BAL_USDT exists, 2nd latest row's date is 2025-04-15
# Get BINANCE_SPOT_BAL_USDT from 2025-04-15 to 2026-01-26
# Fetching BINANCE_SPOT_BAL_USDT from 2025-04-15 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BAL_USDT.csv with 1702 rows
# ------
# Get 51/648
# File ../binance_data/historical/BINANCE_SPOT_ANT_USDT.csv exists, get last row
# Existing file has 1278 rows
# Last date in existing file is 2024-02-19
# File BINANCE_SPOT_ANT_USDT exists, 2nd latest row's date is 2024-02-19
# Get BINANCE_SPOT_ANT_USDT from 2024-02-19 to 2026-01-26
# Fetching BINANCE_SPOT_ANT_USDT from 2024-02-19 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ANT_USDT.csv with 1280 rows
# ------
# Get 52/648
# File ../binance_data/historical/BINANCE_SPOT_CRV_USDT.csv exists, get last row
# Existing file has 1976 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_CRV_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_CRV_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_CRV_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_CRV_USDT.csv with 1982 rows
# ------
# Get 53/648
# File ../binance_data/historical/BINANCE_SPOT_BZRX_USDT.csv exists, get last row
# Existing file has 468 rows
# Last date in existing file is 2021-12-19
# File BINANCE_SPOT_BZRX_USDT exists, 2nd latest row's date is 2021-12-19
# Get BINANCE_SPOT_BZRX_USDT from 2021-12-19 to 2026-01-26
# Fetching BINANCE_SPOT_BZRX_USDT from 2021-12-19 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BZRX_USDT.csv with 470 rows
# ------
# Get 54/648
# File ../binance_data/historical/BINANCE_SPOT_DIA_USDT.csv exists, get last row
# Existing file has 1957 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_DIA_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_DIA_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_DIA_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_DIA_USDT.csv with 1963 rows
# ------
# Get 55/648
# File ../binance_data/historical/BINANCE_SPOT_BEL_USDT.csv exists, get last row
# Existing file has 1945 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_BEL_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_BEL_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_BEL_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BEL_USDT.csv with 1951 rows
# ------
# Get 56/648
# File ../binance_data/historical/BINANCE_SPOT_AVAX_USDT.csv exists, get last row
# Existing file has 1945 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_AVAX_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_AVAX_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_AVAX_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_AVAX_USDT.csv with 1951 rows
# ------
# Get 57/648
# File ../binance_data/historical/BINANCE_SPOT_ALPHA_USDT.csv exists, get last row
# Existing file has 1718 rows
# Last date in existing file is 2025-07-03
# File BINANCE_SPOT_ALPHA_USDT exists, 2nd latest row's date is 2025-07-03
# Get BINANCE_SPOT_ALPHA_USDT from 2025-07-03 to 2026-01-26
# Fetching BINANCE_SPOT_ALPHA_USDT from 2025-07-03 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ALPHA_USDT.csv with 1720 rows
# ------
# Get 58/648
# File ../binance_data/historical/BINANCE_SPOT_AAVE_USDT.csv exists, get last row
# Existing file has 1922 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_AAVE_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_AAVE_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_AAVE_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_AAVE_USDT.csv with 1928 rows
# ------
# Get 59/648
# File ../binance_data/historical/BINANCE_SPOT_AUDIO_USDT.csv exists, get last row
# Existing file has 1908 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_AUDIO_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_AUDIO_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_AUDIO_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_AUDIO_USDT.csv with 1914 rows
# ------
# Get 60/648
# File ../binance_data/historical/BINANCE_SPOT_CTK_USDT.csv exists, get last row
# Existing file has 1904 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_CTK_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_CTK_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_CTK_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_CTK_USDT.csv with 1910 rows
# ------
# Get 61/648
# File ../binance_data/historical/BINANCE_SPOT_BCHUP_USDT.csv exists, get last row
# Existing file has 273 rows
# Last date in existing file is 2022-01-02
# File BINANCE_SPOT_BCHUP_USDT exists, 2nd latest row's date is 2022-01-02
# Get BINANCE_SPOT_BCHUP_USDT from 2022-01-02 to 2026-01-26
# Fetching BINANCE_SPOT_BCHUP_USDT from 2022-01-02 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BCHUP_USDT.csv with 275 rows
# ------
# Get 62/648
# File ../binance_data/historical/BINANCE_SPOT_BCHDOWN_USDT.csv exists, get last row
# Existing file has 274 rows
# Last date in existing file is 2022-01-02
# File BINANCE_SPOT_BCHDOWN_USDT exists, 2nd latest row's date is 2022-01-02
# Get BINANCE_SPOT_BCHDOWN_USDT from 2022-01-02 to 2026-01-26
# Fetching BINANCE_SPOT_BCHDOWN_USDT from 2022-01-02 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BCHDOWN_USDT.csv with 276 rows
# ------
# Get 63/648
# File ../binance_data/historical/BINANCE_SPOT_AKRO_USDT.csv exists, get last row
# Existing file has 1506 rows
# Last date in existing file is 2024-12-24
# File BINANCE_SPOT_AKRO_USDT exists, 2nd latest row's date is 2024-12-24
# Get BINANCE_SPOT_AKRO_USDT from 2024-12-24 to 2026-01-26
# Fetching BINANCE_SPOT_AKRO_USDT from 2024-12-24 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_AKRO_USDT.csv with 1508 rows
# ------
# Get 64/648
# File ../binance_data/historical/BINANCE_SPOT_AXS_USDT.csv exists, get last row
# Existing file has 1895 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_AXS_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_AXS_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_AXS_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_AXS_USDT.csv with 1901 rows
# ------
# Get 65/648
# File ../binance_data/historical/BINANCE_SPOT_DNT_USDT.csv exists, get last row
# Existing file has 704 rows
# Last date in existing file is 2022-10-23
# File BINANCE_SPOT_DNT_USDT exists, 2nd latest row's date is 2022-10-23
# Get BINANCE_SPOT_DNT_USDT from 2022-10-23 to 2026-01-26
# Fetching BINANCE_SPOT_DNT_USDT from 2022-10-23 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_DNT_USDT.csv with 706 rows
# ------
# Get 66/648
# File ../binance_data/historical/BINANCE_SPOT_AVA_USDT.csv exists, get last row
# Existing file has 1875 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_AVA_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_AVA_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_AVA_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_AVA_USDT.csv with 1881 rows
# ------
# Get 67/648
# File ../binance_data/historical/BINANCE_SPOT_AAVEUP_USDT.csv exists, get last row
# Existing file has 342 rows
# Last date in existing file is 2021-11-10
# File BINANCE_SPOT_AAVEUP_USDT exists, 2nd latest row's date is 2021-11-10
# Get BINANCE_SPOT_AAVEUP_USDT from 2021-11-10 to 2026-01-26
# Fetching BINANCE_SPOT_AAVEUP_USDT from 2021-11-10 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_AAVEUP_USDT.csv with 344 rows
# ------
# Get 68/648
# File ../binance_data/historical/BINANCE_SPOT_AAVEDOWN_USDT.csv exists, get last row
# Existing file has 342 rows
# Last date in existing file is 2021-11-10
# File BINANCE_SPOT_AAVEDOWN_USDT exists, 2nd latest row's date is 2021-11-10
# Get BINANCE_SPOT_AAVEDOWN_USDT from 2021-11-10 to 2026-01-26
# Fetching BINANCE_SPOT_AAVEDOWN_USDT from 2021-11-10 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_AAVEDOWN_USDT.csv with 344 rows
# ------
# Get 69/648
# File ../binance_data/historical/BINANCE_SPOT_1INCH_USDT.csv exists, get last row
# Existing file has 1844 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_1INCH_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_1INCH_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_1INCH_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_1INCH_USDT.csv with 1850 rows
# ------
# Get 70/648
# File ../binance_data/historical/BINANCE_SPOT_ATM_USDT.csv exists, get last row
# Existing file has 1839 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_ATM_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_ATM_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_ATM_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ATM_USDT.csv with 1845 rows
# ------
# Get 71/648
# File ../binance_data/historical/BINANCE_SPOT_ASR_USDT.csv exists, get last row
# Existing file has 1838 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_ASR_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_ASR_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_ASR_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ASR_USDT.csv with 1844 rows
# ------
# Get 72/648
# File ../binance_data/historical/BINANCE_SPOT_CELO_USDT.csv exists, get last row
# Existing file has 1833 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_CELO_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_CELO_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_CELO_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_CELO_USDT.csv with 1839 rows
# ------
# Get 73/648
# File ../binance_data/historical/BINANCE_SPOT_BTCST_USDT.csv exists, get last row
# Existing file has 674 rows
# Last date in existing file is 2022-11-27
# File BINANCE_SPOT_BTCST_USDT exists, 2nd latest row's date is 2022-11-27
# Get BINANCE_SPOT_BTCST_USDT from 2022-11-27 to 2026-01-26
# Fetching BINANCE_SPOT_BTCST_USDT from 2022-11-27 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BTCST_USDT.csv with 676 rows
# ------
# Get 74/648
# File ../binance_data/historical/BINANCE_SPOT_CKB_USDT.csv exists, get last row
# Existing file has 1813 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_CKB_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_CKB_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_CKB_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_CKB_USDT.csv with 1819 rows
# ------
# Get 75/648
# File ../binance_data/historical/BINANCE_SPOT_CAKE_USDT.csv exists, get last row
# Existing file has 1788 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_CAKE_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_CAKE_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_CAKE_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_CAKE_USDT.csv with 1794 rows
# ------
# Get 76/648
# File ../binance_data/historical/BINANCE_SPOT_DODO_USDT.csv exists, get last row
# Existing file has 1789 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_DODO_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_DODO_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_DODO_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_DODO_USDT.csv with 1795 rows
# ------
# Get 77/648
# File ../binance_data/historical/BINANCE_SPOT_ACM_USDT.csv exists, get last row
# Existing file has 1784 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_ACM_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_ACM_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_ACM_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ACM_USDT.csv with 1790 rows
# ------
# Get 78/648
# File ../binance_data/historical/BINANCE_SPOT_BADGER_USDT.csv exists, get last row
# Existing file has 1498 rows
# Last date in existing file is 2025-04-15
# File BINANCE_SPOT_BADGER_USDT exists, 2nd latest row's date is 2025-04-15
# Get BINANCE_SPOT_BADGER_USDT from 2025-04-15 to 2026-01-26
# Fetching BINANCE_SPOT_BADGER_USDT from 2025-04-15 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BADGER_USDT.csv with 1500 rows
# ------
# Get 79/648
# File ../binance_data/historical/BINANCE_SPOT_DEGO_USDT.csv exists, get last row
# Existing file has 1769 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_DEGO_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_DEGO_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_DEGO_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_DEGO_USDT.csv with 1775 rows
# ------
# Get 80/648
# File ../binance_data/historical/BINANCE_SPOT_ALICE_USDT.csv exists, get last row
# Existing file has 1765 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_ALICE_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_ALICE_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_ALICE_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ALICE_USDT.csv with 1771 rows
# ------
# Get 81/648
# File ../binance_data/historical/BINANCE_SPOT_CFX_USDT.csv exists, get last row
# Existing file has 1755 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_CFX_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_CFX_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_CFX_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_CFX_USDT.csv with 1761 rows
# ------
# Get 82/648
# File ../binance_data/historical/BINANCE_SPOT_AUTO_USDT.csv exists, get last row
# Existing file has 741 rows
# Last date in existing file is 2023-04-17
# File BINANCE_SPOT_AUTO_USDT exists, 2nd latest row's date is 2023-04-17
# Get BINANCE_SPOT_AUTO_USDT from 2023-04-17 to 2026-01-26
# Fetching BINANCE_SPOT_AUTO_USDT from 2023-04-17 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_AUTO_USDT.csv with 743 rows
# ------
# Get 83/648
# File ../binance_data/historical/BINANCE_SPOT_1INCHUP_USDT.csv exists, get last row
# Existing file has 228 rows
# Last date in existing file is 2021-12-01
# File BINANCE_SPOT_1INCHUP_USDT exists, 2nd latest row's date is 2021-12-01
# Get BINANCE_SPOT_1INCHUP_USDT from 2021-12-01 to 2026-01-26
# Fetching BINANCE_SPOT_1INCHUP_USDT from 2021-12-01 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_1INCHUP_USDT.csv with 230 rows
# ------
# Get 84/648
# File ../binance_data/historical/BINANCE_SPOT_1INCHDOWN_USDT.csv exists, get last row
# Existing file has 229 rows
# Last date in existing file is 2021-12-01
# File BINANCE_SPOT_1INCHDOWN_USDT exists, 2nd latest row's date is 2021-12-01
# Get BINANCE_SPOT_1INCHDOWN_USDT from 2021-12-01 to 2026-01-26
# Fetching BINANCE_SPOT_1INCHDOWN_USDT from 2021-12-01 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_1INCHDOWN_USDT.csv with 231 rows
# ------
# Get 85/648
# File ../binance_data/historical/BINANCE_SPOT_BTG_USDT.csv exists, get last row
# Existing file has 553 rows
# Last date in existing file is 2022-10-23
# File BINANCE_SPOT_BTG_USDT exists, 2nd latest row's date is 2022-10-23
# Get BINANCE_SPOT_BTG_USDT from 2022-10-23 to 2026-01-26
# Fetching BINANCE_SPOT_BTG_USDT from 2022-10-23 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BTG_USDT.csv with 555 rows
# ------
# Get 86/648
# File ../binance_data/historical/BINANCE_SPOT_BAR_USDT.csv exists, get last row
# Existing file has 1732 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_BAR_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_BAR_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_BAR_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BAR_USDT.csv with 1738 rows
# ------
# Get 87/648
# File ../binance_data/historical/BINANCE_SPOT_BAKE_USDT.csv exists, get last row
# Existing file has 1596 rows
# Last date in existing file is 2025-09-16
# File BINANCE_SPOT_BAKE_USDT exists, 2nd latest row's date is 2025-09-16
# Get BINANCE_SPOT_BAKE_USDT from 2025-09-16 to 2026-01-26
# Fetching BINANCE_SPOT_BAKE_USDT from 2025-09-16 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BAKE_USDT.csv with 1598 rows
# ------
# Get 88/648
# File ../binance_data/historical/BINANCE_SPOT_BURGER_USDT.csv exists, get last row
# Existing file has 1424 rows
# Last date in existing file is 2025-03-27
# File BINANCE_SPOT_BURGER_USDT exists, 2nd latest row's date is 2025-03-27
# Get BINANCE_SPOT_BURGER_USDT from 2025-03-27 to 2026-01-26
# Fetching BINANCE_SPOT_BURGER_USDT from 2025-03-27 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BURGER_USDT.csv with 1426 rows
# ------
# Get 89/648
# File ../binance_data/historical/BINANCE_SPOT_AR_USDT.csv exists, get last row
# Existing file has 1708 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_AR_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_AR_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_AR_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_AR_USDT.csv with 1714 rows
# ------
# Get 90/648
# File ../binance_data/historical/BINANCE_SPOT_ATA_USDT.csv exists, get last row
# Existing file has 1685 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_ATA_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_ATA_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_ATA_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ATA_USDT.csv with 1691 rows
# ------
# Get 91/648
# File ../binance_data/historical/BINANCE_SPOT_BOND_USDT.csv exists, get last row
# Existing file has 1108 rows
# Last date in existing file is 2024-07-21
# File BINANCE_SPOT_BOND_USDT exists, 2nd latest row's date is 2024-07-21
# Get BINANCE_SPOT_BOND_USDT from 2024-07-21 to 2026-01-26
# Fetching BINANCE_SPOT_BOND_USDT from 2024-07-21 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BOND_USDT.csv with 1110 rows
# ------
# Get 92/648
# File ../binance_data/historical/BINANCE_SPOT_DEXE_USDT.csv exists, get last row
# Existing file has 1639 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_DEXE_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_DEXE_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_DEXE_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_DEXE_USDT.csv with 1645 rows
# ------
# Get 93/648
# File ../binance_data/historical/BINANCE_SPOT_C98_USDT.csv exists, get last row
# Existing file has 1639 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_C98_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_C98_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_C98_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_C98_USDT.csv with 1645 rows
# ------
# Get 94/648
# File ../binance_data/historical/BINANCE_SPOT_CLV_USDT.csv exists, get last row
# Existing file has 1302 rows
# Last date in existing file is 2025-02-23
# File BINANCE_SPOT_CLV_USDT exists, 2nd latest row's date is 2025-02-23
# Get BINANCE_SPOT_CLV_USDT from 2025-02-23 to 2026-01-26
# Fetching BINANCE_SPOT_CLV_USDT from 2025-02-23 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_CLV_USDT.csv with 1304 rows
# ------
# Get 95/648
# File ../binance_data/historical/BINANCE_SPOT_ALPACA_USDT.csv exists, get last row
# Existing file has 1356 rows
# Last date in existing file is 2025-05-01
# File BINANCE_SPOT_ALPACA_USDT exists, 2nd latest row's date is 2025-05-01
# Get BINANCE_SPOT_ALPACA_USDT from 2025-05-01 to 2026-01-26
# Fetching BINANCE_SPOT_ALPACA_USDT from 2025-05-01 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ALPACA_USDT.csv with 1358 rows
# ------
# Get 96/648
# File ../binance_data/historical/BINANCE_SPOT_DF_USDT.csv exists, get last row
# Existing file has 1577 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_DF_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_DF_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_DF_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_DF_USDT.csv with 1583 rows
# ------
# Get 97/648
# File ../binance_data/historical/BINANCE_SPOT_CVP_USDT.csv exists, get last row
# Existing file has 1054 rows
# Last date in existing file is 2024-08-25
# File BINANCE_SPOT_CVP_USDT exists, 2nd latest row's date is 2024-08-25
# Get BINANCE_SPOT_CVP_USDT from 2024-08-25 to 2026-01-26
# Fetching BINANCE_SPOT_CVP_USDT from 2024-08-25 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_CVP_USDT.csv with 1056 rows
# ------
# Get 98/648
# File ../binance_data/historical/BINANCE_SPOT_AGLD_USDT.csv exists, get last row
# Existing file has 1566 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_AGLD_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_AGLD_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_AGLD_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_AGLD_USDT.csv with 1572 rows
# ------
# Get 99/648
# File ../binance_data/historical/BINANCE_SPOT_BETA_USDT.csv exists, get last row
# Existing file has 1283 rows
# Last date in existing file is 2025-04-15
# File BINANCE_SPOT_BETA_USDT exists, 2nd latest row's date is 2025-04-15
# Get BINANCE_SPOT_BETA_USDT from 2025-04-15 to 2026-01-26
# Fetching BINANCE_SPOT_BETA_USDT from 2025-04-15 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BETA_USDT.csv with 1285 rows
# ------
# Get 100/648
# File ../binance_data/historical/BINANCE_SPOT_CHESS_USDT.csv exists, get last row
# Existing file has 1549 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_CHESS_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_CHESS_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_CHESS_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_CHESS_USDT.csv with 1555 rows
# ------
# Get 101/648
# File ../binance_data/historical/BINANCE_SPOT_ADX_USDT.csv exists, get last row
# Existing file has 1542 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_ADX_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_ADX_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_ADX_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ADX_USDT.csv with 1548 rows
# ------
# Get 102/648
# File ../binance_data/historical/BINANCE_SPOT_AUCTION_USDT.csv exists, get last row
# Existing file has 1542 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_AUCTION_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_AUCTION_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_AUCTION_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_AUCTION_USDT.csv with 1548 rows
# ------
# Get 103/648
# File ../binance_data/historical/BINANCE_SPOT_DAR_USDT.csv exists, get last row
# Existing file has 1156 rows
# Last date in existing file is 2025-01-05
# File BINANCE_SPOT_DAR_USDT exists, 2nd latest row's date is 2025-01-05
# Get BINANCE_SPOT_DAR_USDT from 2025-01-05 to 2026-01-26
# Fetching BINANCE_SPOT_DAR_USDT from 2025-01-05 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_DAR_USDT.csv with 1158 rows
# ------
# Get 104/648
# File ../binance_data/historical/BINANCE_SPOT_BNX_USDT.csv exists, get last row
# Existing file has 1222 rows
# Last date in existing file is 2025-03-17
# File BINANCE_SPOT_BNX_USDT exists, 2nd latest row's date is 2025-03-17
# Get BINANCE_SPOT_BNX_USDT from 2025-03-17 to 2026-01-26
# Fetching BINANCE_SPOT_BNX_USDT from 2025-03-17 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_BNX_USDT.csv with 1224 rows
# ------
# Get 105/648
# File ../binance_data/historical/BINANCE_SPOT_CITY_USDT.csv exists, get last row
# Existing file has 1530 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_CITY_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_CITY_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_CITY_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_CITY_USDT.csv with 1536 rows
# ------
# Get 106/648
# File ../binance_data/historical/BINANCE_SPOT_AMP_USDT.csv exists, get last row
# Existing file has 1517 rows
# Last date in existing file is 2026-01-20
# ...
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_T_USDT.csv with 1430 rows
# ------
# Get 614/648
# File ../binance_data/historical/BINANCE_SPOT_VIB_USDT.csv exists, get last row
# Existing file has 796 rows
# Last date in existing file is 2025-05-01
# File BINANCE_SPOT_VIB_USDT exists, 2nd latest row's date is 2025-05-01
# Get BINANCE_SPOT_VIB_USDT from 2025-05-01 to 2026-01-26
# Fetching BINANCE_SPOT_VIB_USDT from 2025-05-01 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_VIB_USDT.csv with 798 rows
# ------
# Get 615/648
# File ../binance_data/historical/BINANCE_SPOT_USTC_USDT.csv exists, get last row
# Existing file has 1046 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_USTC_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_USTC_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_USTC_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_USTC_USDT.csv with 1052 rows
# ------
# Get 616/648
# File ../binance_data/historical/BINANCE_SPOT_UFT_USDT.csv exists, get last row
# Existing file has 759 rows
# Last date in existing file is 2025-04-15
# File BINANCE_SPOT_UFT_USDT exists, 2nd latest row's date is 2025-04-15
# Get BINANCE_SPOT_UFT_USDT from 2025-04-15 to 2026-01-26
# Fetching BINANCE_SPOT_UFT_USDT from 2025-04-15 to 2026-01-26 …
# Fetched 2 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_UFT_USDT.csv with 761 rows
# ------
# Get 617/648
# File ../binance_data/historical/BINANCE_SPOT_WBTC_USDT.csv exists, get last row
# Existing file has 997 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_WBTC_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_WBTC_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_WBTC_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_WBTC_USDT.csv with 1003 rows
# ------
# Get 618/648
# File ../binance_data/historical/BINANCE_SPOT_WBETH_USDT.csv exists, get last row
# Existing file has 916 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_WBETH_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_WBETH_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_WBETH_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_WBETH_USDT.csv with 922 rows
# ------
# Get 619/648
# File ../binance_data/historical/BINANCE_SPOT_WLD_USDT.csv exists, get last row
# Existing file has 911 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_WLD_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_WLD_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_WLD_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_WLD_USDT.csv with 917 rows
# ------
# Get 620/648
# File ../binance_data/historical/BINANCE_SPOT_VIC_USDT.csv exists, get last row
# Existing file has 788 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_VIC_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_VIC_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_VIC_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_VIC_USDT.csv with 794 rows
# ------
# Get 621/648
# File ../binance_data/historical/BINANCE_SPOT_VANRY_USDT.csv exists, get last row
# Existing file has 781 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_VANRY_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_VANRY_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_VANRY_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_VANRY_USDT.csv with 787 rows
# ------
# Get 622/648
# File ../binance_data/historical/BINANCE_SPOT_XAI_USDT.csv exists, get last row
# Existing file has 742 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_XAI_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_XAI_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_XAI_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_XAI_USDT.csv with 748 rows
# ------
# Get 623/648
# File ../binance_data/historical/BINANCE_SPOT_WIF_USDT.csv exists, get last row
# Existing file has 686 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_WIF_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_WIF_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_WIF_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_WIF_USDT.csv with 692 rows
# ------
# Get 624/648
# File ../binance_data/historical/BINANCE_SPOT_W_USDT.csv exists, get last row
# Existing file has 657 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_W_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_W_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_W_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_W_USDT.csv with 663 rows
# ------
# Get 625/648
# File ../binance_data/historical/BINANCE_SPOT_ZK_USDT.csv exists, get last row
# Existing file has 582 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_ZK_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_ZK_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_ZK_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ZK_USDT.csv with 588 rows
# ------
# Get 626/648
# File ../binance_data/historical/BINANCE_SPOT_ZRO_USDT.csv exists, get last row
# Existing file has 579 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_ZRO_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_ZRO_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_ZRO_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ZRO_USDT.csv with 585 rows
# ------
# Get 627/648
# File ../binance_data/historical/BINANCE_SPOT_TURBO_USDT.csv exists, get last row
# Existing file has 491 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_TURBO_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_TURBO_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_TURBO_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_TURBO_USDT.csv with 497 rows
# ------
# Get 628/648
# File ../binance_data/historical/BINANCE_SPOT_USUAL_USDT.csv exists, get last row
# Existing file has 427 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_USUAL_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_USUAL_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_USUAL_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_USUAL_USDT.csv with 433 rows
# ------
# Get 629/648
# File ../binance_data/historical/BINANCE_SPOT_VELODROME_USDT.csv exists, get last row
# Existing file has 403 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_VELODROME_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_VELODROME_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_VELODROME_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_VELODROME_USDT.csv with 409 rows
# ------
# Get 630/648
# File ../binance_data/historical/BINANCE_SPOT_VANA_USDT.csv exists, get last row
# Existing file has 400 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_VANA_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_VANA_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_VANA_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_VANA_USDT.csv with 406 rows
# ------
# Get 631/648
# File ../binance_data/historical/BINANCE_SPOT_TRUMP_USDT.csv exists, get last row
# Existing file has 366 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_TRUMP_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_TRUMP_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_TRUMP_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_TRUMP_USDT.csv with 372 rows
# ------
# Get 632/648
# File ../binance_data/historical/BINANCE_SPOT_TST_USDT.csv exists, get last row
# Existing file has 345 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_TST_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_TST_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_TST_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_TST_USDT.csv with 351 rows
# ------
# Get 633/648
# File ../binance_data/historical/BINANCE_SPOT_XUSD_USDT.csv exists, get last row
# Existing file has 307 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_XUSD_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_XUSD_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_XUSD_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_XUSD_USDT.csv with 313 rows
# ------
# Get 634/648
# File ../binance_data/historical/BINANCE_SPOT_TUT_USDT.csv exists, get last row
# Existing file has 299 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_TUT_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_TUT_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_TUT_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_TUT_USDT.csv with 305 rows
# ------
# Get 635/648
# File ../binance_data/historical/BINANCE_SPOT_VIRTUAL_USDT.csv exists, get last row
# Existing file has 284 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_VIRTUAL_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_VIRTUAL_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_VIRTUAL_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_VIRTUAL_USDT.csv with 290 rows
# ------
# Get 636/648
# File ../binance_data/historical/BINANCE_SPOT_WCT_USDT.csv exists, get last row
# Existing file has 280 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_WCT_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_WCT_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_WCT_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_WCT_USDT.csv with 286 rows
# ------
# Get 637/648
# File ../binance_data/historical/BINANCE_SPOT_USD1_USDT.csv exists, get last row
# Existing file has 243 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_USD1_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_USD1_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_USD1_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_USD1_USDT.csv with 249 rows
# ------
# Get 638/648
# File ../binance_data/historical/BINANCE_SPOT_TREE_USDT.csv exists, get last row
# Existing file has 175 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_TREE_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_TREE_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_TREE_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_TREE_USDT.csv with 181 rows
# ------
# Get 639/648
# File ../binance_data/historical/BINANCE_SPOT_WLFI_USDT.csv exists, get last row
# Existing file has 141 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_WLFI_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_WLFI_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_WLFI_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_WLFI_USDT.csv with 147 rows
# ------
# Get 640/648
# File ../binance_data/historical/BINANCE_SPOT_USDE_USDT.csv exists, get last row
# Existing file has 133 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_USDE_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_USDE_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_USDE_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_USDE_USDT.csv with 139 rows
# ------
# Get 641/648
# File ../binance_data/historical/BINANCE_SPOT_ZKC_USDT.csv exists, get last row
# Existing file has 127 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_ZKC_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_ZKC_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_ZKC_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ZKC_USDT.csv with 133 rows
# ------
# Get 642/648
# File ../binance_data/historical/BINANCE_SPOT_XPL_USDT.csv exists, get last row
# Existing file has 117 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_XPL_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_XPL_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_XPL_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_XPL_USDT.csv with 123 rows
# ------
# Get 643/648
# File ../binance_data/historical/BINANCE_SPOT_WAL_USDT.csv exists, get last row
# Existing file has 102 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_WAL_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_WAL_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_WAL_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_WAL_USDT.csv with 108 rows
# ------
# Get 644/648
# File ../binance_data/historical/BINANCE_SPOT_YB_USDT.csv exists, get last row
# Existing file has 97 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_YB_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_YB_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_YB_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_YB_USDT.csv with 103 rows
# ------
# Get 645/648
# File ../binance_data/historical/BINANCE_SPOT_ZBT_USDT.csv exists, get last row
# Existing file has 95 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_ZBT_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_ZBT_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_ZBT_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ZBT_USDT.csv with 101 rows
# ------
# Get 646/648
# File ../binance_data/historical/BINANCE_SPOT_TURTLE_USDT.csv exists, get last row
# Existing file has 90 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_TURTLE_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_TURTLE_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_TURTLE_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_TURTLE_USDT.csv with 96 rows
# ------
# Get 647/648
# File ../binance_data/historical/BINANCE_SPOT_ZKP_USDT.csv exists, get last row
# Existing file has 13 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_ZKP_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_ZKP_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_ZKP_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_ZKP_USDT.csv with 19 rows
# ------
# Get 648/648
# File ../binance_data/historical/BINANCE_SPOT_U_USDT.csv exists, get last row
# Existing file has 7 rows
# Last date in existing file is 2026-01-20
# File BINANCE_SPOT_U_USDT exists, 2nd latest row's date is 2026-01-20
# Get BINANCE_SPOT_U_USDT from 2026-01-20 to 2026-01-26
# Fetching BINANCE_SPOT_U_USDT from 2026-01-20 to 2026-01-26 …
# Fetched 6 bars
# Wrote file ../binance_data/historical/BINANCE_SPOT_U_USDT.csv with 13 rows
# Out of 648 cryptos, 648 were fetched

# %%
# Turns out: /history returns active *and* delisted data
for symbol_id in active:
    if (symbol_id not in historical):
        print(f'!!!!! Active symbol {symbol_id} not in historical list')
#     file_path = f'{output_folder}/active/{symbol_id}.csv'
#     start_date = get_latest_entry_date(file_path) or first_date
#     end_date = date.today()
#     if (start_date >= end_date):
#         print(f'Skip {symbol_id}, start is on or after end')
#         continue
#     print(f'Get {symbol_id} from {start_date}')
#     data = coinapi_fetcher.get_history(symbol_id, start_date)
#     write_file(data, file_path)
#     time.sleep(1)

# print('Done')
