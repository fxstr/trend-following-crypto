# %% [markdown]
# Why Coinapi?
# - Delisted symbols
# - Long history (back to the origins)
# - Cleaned data
# - Pricing quite fair and usage-based (Coinmarketcap costs $700/month for the same)

# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
from datetime import datetime, date
import os
from matplotlib import pyplot as plt
import coinapi_fetcher
import time

output_folder = '../coinapi_data'

# %%
# btc = coinapi_fetcher.get_history('COINBASE_SPOT_BTC_USD', datetime(2010, 1, 1))
# btc['close'].plot(figsize=(15, 6))
# plt.show()
# btc.to_csv(os.path.join(output_folder, 'COINBASE_SPOT_BTC_USD.csv'), index=True)

# %%
# Binance doesn't have base currency USD; use BTC and re-caculate (BINANCE has a market share
# of approx 40%)
# Problem: There is no BTC-BTC, so we don't get the BTC volume. Use Coinbase instead, as they
# directly quote USD.
exchange_id = 'COINBASE'
active = coinapi_fetcher.get_active_symbols(exchange_id)
historical = coinapi_fetcher.get_historical_symbols(exchange_id)

print(f'Got {len(active)} active and {len(historical)} historical symbols')
print(f'Active symbols: {active}.to_list()')
print(f'Historical symbols: {historical}.to_list()')
# Out:
# Get active symbols for COINBASE
# Get historical symbols for COINBASE, adding to 0 existing
# Out of 814 historical, 401 are USD-based
# Got 330 active and 401 historical symbols
# Active symbols: ['COINBASE_SPOT_AVNT_USD', 'COINBASE_SPOT_ACH_USD', 'COINBASE_SPOT_DASH_USD', 'COINBASE_SPOT_ARKM_USD', 'COINBASE_SPOT_AKT_USD', 'COINBASE_SPOT_IO_USD', 'COINBASE_SPOT_SEAM_USD', 'COINBASE_SPOT_VTHO_USD', 'COINBASE_SPOT_BCH_USD', 'COINBASE_SPOT_APE_USD', 'COINBASE_SPOT_RENDER_USD', 'COINBASE_SPOT_API3_USD', 'COINBASE_SPOT_AST_USD', 'COINBASE_SPOT_FLOKI_USD', 'COINBASE_SPOT_FLR_USD', 'COINBASE_SPOT_IOTX_USD', 'COINBASE_SPOT_CRO_USD', 'COINBASE_SPOT_WLD_USD', 'COINBASE_SPOT_ETHFI_USD', 'COINBASE_SPOT_SUKU_USD', 'COINBASE_SPOT_FORT_USD', 'COINBASE_SPOT_ZEN_USD', 'COINBASE_SPOT_RED_USD', 'COINBASE_SPOT_USDS_USD', 'COINBASE_SPOT_RAD_USD', 'COINBASE_SPOT_AVAX_USD', 'COINBASE_SPOT_AERO_USD', 'COINBASE_SPOT_ICP_USD', 'COINBASE_SPOT_DOGINME_USD', 'COINBASE_SPOT_XCN_USD', 'COINBASE_SPOT_GNO_USD', 'COINBASE_SPOT_SHPING_USD', 'COINBASE_SPOT_XAN_USD', 'COINBASE_SPOT_OMNI_USD', 'COINBASE_SPOT_STORJ_USD', 'COINBASE_SPOT_MAMO_USD', 'COINBASE_SPOT_BADGER_USD', 'COINBASE_SPOT_ZEC_USD', 'COINBASE_SPOT_CELR_USD', 'COINBASE_SPOT_BLZ_USD', 'COINBASE_SPOT_POND_USD', 'COINBASE_SPOT_TRUMP_USD', 'COINBASE_SPOT_PNUT_USD', 'COINBASE_SPOT_KMNO_USD', 'COINBASE_SPOT_RLC_USD', 'COINBASE_SPOT_RPL_USD', 'COINBASE_SPOT_KAITO_USD', 'COINBASE_SPOT_INDEX_USD', 'COINBASE_SPOT_FLOCK_USD', 'COINBASE_SPOT_PLU_USD', 'COINBASE_SPOT_FIDA_USD', 'COINBASE_SPOT_SYND_USD', 'COINBASE_SPOT_ZRX_USD', 'COINBASE_SPOT_1INCH_USD', 'COINBASE_SPOT_GST_USD', 'COINBASE_SPOT_LINEA_USD', 'COINBASE_SPOT_DRIFT_USD', 'COINBASE_SPOT_CHZ_USD', 'COINBASE_SPOT_BLAST_USD', 'COINBASE_SPOT_SXT_USD', 'COINBASE_SPOT_PRIME_USD', 'COINBASE_SPOT_LOKA_USD', 'COINBASE_SPOT_VOXEL_USD', 'COINBASE_SPOT_TRU_USD', 'COINBASE_SPOT_LA_USD', 'COINBASE_SPOT_SOL_USD', 'COINBASE_SPOT_IMX_USD', 'COINBASE_SPOT_VARA_USD', 'COINBASE_SPOT_PRCL_USD', 'COINBASE_SPOT_CTSI_USD', 'COINBASE_SPOT_EUL_USD', 'COINBASE_SPOT_POL_USD', 'COINBASE_SPOT_POPCAT_USD', 'COINBASE_SPOT_ALEO_USD', 'COINBASE_SPOT_FIL_USD', 'COINBASE_SPOT_WAXL_USD', 'COINBASE_SPOT_KNC_USD', 'COINBASE_SPOT_KERNEL_USD', 'COINBASE_SPOT_SNX_USD', 'COINBASE_SPOT_KRL_USD', 'COINBASE_SPOT_STX_USD', 'COINBASE_SPOT_SPX_USD', 'COINBASE_SPOT_CLANKER_USD', 'COINBASE_SPOT_BARD_USD', 'COINBASE_SPOT_AXL_USD', 'COINBASE_SPOT_DEGEN_USD', 'COINBASE_SPOT_VVV_USD', 'COINBASE_SPOT_WELL_USD', 'COINBASE_SPOT_MLN_USD', 'COINBASE_SPOT_HFT_USD', 'COINBASE_SPOT_KARRAT_USD', 'COINBASE_SPOT_MASK_USD', 'COINBASE_SPOT_RARE_USD', 'COINBASE_SPOT_QNT_USD', 'COINBASE_SPOT_RSR_USD', 'COINBASE_SPOT_SAFE_USD', 'COINBASE_SPOT_TRB_USD', 'COINBASE_SPOT_MNDE_USD', 'COINBASE_SPOT_STRK_USD', 'COINBASE_SPOT_ALEPH_USD', 'COINBASE_SPOT_USELESS_USD', 'COINBASE_SPOT_POWR_USD', 'COINBASE_SPOT_ZETACHAIN_USD', 'COINBASE_SPOT_ROSE_USD', 'COINBASE_SPOT_CBETH_USD', 'COINBASE_SPOT_LTC_USD', 'COINBASE_SPOT_LRC_USD', 'COINBASE_SPOT_GLM_USD', 'COINBASE_SPOT_MDT_USD', 'COINBASE_SPOT_PAX_USD', 'COINBASE_SPOT_ILV_USD', 'COINBASE_SPOT_MATH_USD', 'COINBASE_SPOT_INV_USD', 'COINBASE_SPOT_JASMY_USD', 'COINBASE_SPOT_HONEY_USD', 'COINBASE_SPOT_BTC_USD', 'COINBASE_SPOT_ABT_USD', 'COINBASE_SPOT_TROLL_USD', 'COINBASE_SPOT_ALGO_USD', 'COINBASE_SPOT_VET_USD', 'COINBASE_SPOT_HNT_USD', 'COINBASE_SPOT_HOME_USD', 'COINBASE_SPOT_USD1_USD', 'COINBASE_SPOT_WCT_USD', 'COINBASE_SPOT_XYO_USD', 'COINBASE_SPOT_S_USD', 'COINBASE_SPOT_T_USD', 'COINBASE_SPOT_W_USD', 'COINBASE_SPOT_OGN_USD', 'COINBASE_SPOT_PROVE_USD', 'COINBASE_SPOT_SUI_USD', 'COINBASE_SPOT_G_USD', 'COINBASE_SPOT_YFI_USD', 'COINBASE_SPOT_ETC_USD', 'COINBASE_SPOT_BLUR_USD', 'COINBASE_SPOT_00_USD', 'COINBASE_SPOT_ZETA_USD', 'COINBASE_SPOT_GMT_USD', 'COINBASE_SPOT_OXT_USD', 'COINBASE_SPOT_SWFTC_USD', 'COINBASE_SPOT_BAL_USD', 'COINBASE_SPOT_TIME_USD', 'COINBASE_SPOT_DOLO_USD', 'COINBASE_SPOT_CVC_USD', 'COINBASE_SPOT_MINA_USD', 'COINBASE_SPOT_LPT_USD', 'COINBASE_SPOT_NEAR_USD', 'COINBASE_SPOT_ARB_USD', 'COINBASE_SPOT_COW_USD', 'COINBASE_SPOT_COTI_USD', 'COINBASE_SPOT_ALT_USD', 'COINBASE_SPOT_QI_USD', 'COINBASE_SPOT_SD_USD', 'COINBASE_SPOT_RARI_USD', 'COINBASE_SPOT_SUPER_ ...
# Historical symbols: ['COINBASE_SPOT_BTC_USD', 'COINBASE_SPOT_ETH_USD', 'COINBASE_SPOT_LTC_USD', 'COINBASE_SPOT_BCH_USD', 'COINBASE_SPOT_ETC_USD', 'COINBASE_SPOT_ZRX_USD', 'COINBASE_SPOT_XRP_USD', 'COINBASE_SPOT_XLM_USD', 'COINBASE_SPOT_EOS_USD', 'COINBASE_SPOT_REP_USD', 'COINBASE_SPOT_LINK_USD', 'COINBASE_SPOT_XTZ_USD', 'COINBASE_SPOT_ALGO_USD', 'COINBASE_SPOT_DASH_USD', 'COINBASE_SPOT_OXT_USD', 'COINBASE_SPOT_ATOM_USD', 'COINBASE_SPOT_KNC_USD', 'COINBASE_SPOT_DAI_USD', 'COINBASE_SPOT_OMG_USD', 'COINBASE_SPOT_MKR_USD', 'COINBASE_SPOT_COMP_USD', 'COINBASE_SPOT_BAND_USD', 'COINBASE_SPOT_NMR_USD', 'COINBASE_SPOT_CGLD_USD', 'COINBASE_SPOT_UMA_USD', 'COINBASE_SPOT_LRC_USD', 'COINBASE_SPOT_YFI_USD', 'COINBASE_SPOT_UNI_USD', 'COINBASE_SPOT_REN_USD', 'COINBASE_SPOT_BAL_USD', 'COINBASE_SPOT_WBTC_USD', 'COINBASE_SPOT_NU_USD', 'COINBASE_SPOT_FIL_USD', 'COINBASE_SPOT_ZEC_USD', 'COINBASE_SPOT_BNT_USD', 'COINBASE_SPOT_SNX_USD', 'COINBASE_SPOT_AAVE_USD', 'COINBASE_SPOT_GRT_USD', 'COINBASE_SPOT_SUSHI_USD', 'COINBASE_SPOT_MATIC_USD', 'COINBASE_SPOT_SKL_USD', 'COINBASE_SPOT_ADA_USD', 'COINBASE_SPOT_CRV_USD', 'COINBASE_SPOT_STORJ_USD', 'COINBASE_SPOT_ANKR_USD', 'COINBASE_SPOT_OGN_USD', 'COINBASE_SPOT_ENJ_USD', 'COINBASE_SPOT_1INCH_USD', 'COINBASE_SPOT_NKN_USD', 'COINBASE_SPOT_BAT_USD', 'COINBASE_SPOT_MANA_USD', 'COINBASE_SPOT_FORTH_USD', 'COINBASE_SPOT_USDT_USD', 'COINBASE_SPOT_TRB_USD', 'COINBASE_SPOT_RLC_USD', 'COINBASE_SPOT_MIR_USD', 'COINBASE_SPOT_CTSI_USD', 'COINBASE_SPOT_ICP_USD', 'COINBASE_SPOT_SOL_USD', 'COINBASE_SPOT_DOGE_USD', 'COINBASE_SPOT_AMP_USD', 'COINBASE_SPOT_MLN_USD', 'COINBASE_SPOT_GTC_USD', 'COINBASE_SPOT_DOT_USD', 'COINBASE_SPOT_CHZ_USD', 'COINBASE_SPOT_SHIB_USD', 'COINBASE_SPOT_KEEP_USD', 'COINBASE_SPOT_BOND_USD', 'COINBASE_SPOT_LPT_USD', 'COINBASE_SPOT_QNT_USD', 'COINBASE_SPOT_RLY_USD', 'COINBASE_SPOT_MASK_USD', 'COINBASE_SPOT_CLV_USD', 'COINBASE_SPOT_FET_USD', 'COINBASE_SPOT_PAX_USD', 'COINBASE_SPOT_FARM_USD', 'COINBASE_SPOT_POLY_USD', 'COINBASE_SPOT_PLA_USD', 'COINBASE_SPOT_ACH_USD', 'COINBASE_SPOT_RAI_USD', 'COINBASE_SPOT_TRIBE_USD', 'COINBASE_SPOT_UST_USD', 'COINBASE_SPOT_IOTX_USD', 'COINBASE_SPOT_ORN_USD', 'COINBASE_SPOT_QUICK_USD', 'COINBASE_SPOT_TRU_USD', 'COINBASE_SPOT_AXS_USD', 'COINBASE_SPOT_REQ_USD', 'COINBASE_SPOT_WLUNA_USD', 'COINBASE_SPOT_COTI_USD', 'COINBASE_SPOT_DDX_USD', 'COINBASE_SPOT_RAD_USD', 'COINBASE_SPOT_YFII_USD', 'COINBASE_SPOT_XYO_USD', 'COINBASE_SPOT_RGT_USD', 'COINBASE_SPOT_BTRST_USD', 'COINBASE_SPOT_ZEN_USD', 'COINBASE_SPOT_AGLD_USD', 'COINBASE_SPOT_AVAX_USD', 'COINBASE_SPOT_FX_USD', 'COINBASE_SPOT_JASMY_USD', 'COINBASE_SPOT_TBTC_USD', 'COINBASE_SPOT_WCFG_USD', 'COINBASE_SPOT_BADGER_USD', 'COINBASE_SPOT_RARI_USD', 'COINBASE_SPOT_PERP_USD', 'COINBASE_SPOT_ARPA_USD', 'COINBASE_SPOT_AUCTION_USD', 'COINBASE_SPOT_ASM_USD', 'COINBASE_SPOT_SUKU_USD', 'COINBASE_SPOT_TRAC_USD', 'COINBASE_SPOT_KRL_USD', 'COINBASE_SPOT_LCX_USD', 'COINBASE_SPOT_CRO_USD', 'COINBASE_SPOT_CVC_USD', 'COINBASE_SPOT_DNT_USD', 'COINBASE_SPOT_LOOM_USD', 'COINBASE_SPOT_GYEN_USD', 'COINBASE_SPOT_GALA_USD', 'COINBASE_SPOT_MUSD_USD', 'COINBASE_SPOT_ALCX_USD', 'COINBASE_SPOT_ENS_USD', 'COINBASE_SPOT_POWR_USD', 'COINBASE_SPOT_VGX_USD', 'COINBASE_SPOT_BICO_USD', 'COINBASE_SPOT_POLS_USD', 'COINBASE_SPOT_MCO2_USD', 'COINBASE_SPOT_SUPER_USD', 'COINBASE_SPOT_COVAL_USD', 'COINBASE_SPOT_FOX_USD', 'COINBASE_SPOT_SPELL_USD', 'COINBASE_SPOT_IDEX_USD', 'COINBASE_SPOT_API3_USD', 'COINBASE_SPOT_MDT_USD', 'COINBASE_SPOT_RBN_USD', 'COINBASE_SPOT_BLZ_USD', 'COINBASE_SPOT_IMX_USD', 'COINBASE_SPOT_GODS_USD', 'COINBASE_SPOT_DESO_USD', 'COINBASE_SPOT_GFI_USD', 'COINBASE_SPOT_NCT_USD', 'COINBASE_SPOT_PRO_USD', 'COINBASE_SPOT_LQTY_USD', 'COINBASE_SPOT_INV_USD', 'COINBASE_SPOT_STX_USD', 'COINBASE_SPOT_SHPING_USD', 'COINBASE_SPOT_PLU_USD', 'COINBASE_SPOT_UNFI_USD', 'COINBASE_SPOT_DIA_USD', 'COINBASE_SPOT_CTX_USD', 'COINBASE_SPOT_MPL_USD', 'COINBASE_SPOT_ORCA_USD', 'COINBASE_SPOT_FIDA_USD', 'COINBASE_SPOT_QSP_USD', 'COINBASE_SPOT_AVT_USD', 'COINBASE_SPOT_RNDR_U ...

# %%
def write_file(data, file_path):
    data.to_csv(file_path, index=True)
    print(f'Wrote file {file_path} with {len(data)} rows')

def get_existing_content(file_path):
    '''
    Returns the date of the last row in the file, if it exists, and its whole content (which
    is needed to append new data to later).
    '''
    if os.path.exists(file_path):
        print(f'File {file_path} exists, get last row')
        content = pd.read_csv(file_path)
        # When the file is empty, there's no 'date' column that we can use as index; return an
        # empty df so that all data is fetched from the crypto's start of existence.
        if ('date' not in content.columns):
            print('File is missing date column, return empty DataFrame')
            return (pd.DataFrame(), None)
        # Remove the last row; it may contain intraday data; make it 2 to be sure.
        content = content.iloc[:-2]
        content['date'] = pd.to_datetime(content['date'])
        content.set_index('date', inplace=True)
        print(f'Existing file has {len(content)} rows')
        if(len(content)):
            last_date = content.index[-1].date()
            print(f'Last date in existing file is {last_date}')
            return (content, last_date)
        return (content, None)
    else:
        return (pd.DataFrame(), None)

output_folder = '../coinapi_data'
first_date = date(2010, 1, 1)

current_index = 0
# Historical contains *all* cryptos, delisted as well as active. Delisted ones just won't return
# any new data.
for symbol_id in historical:
    current_index += 1
    print('------')
    print(f'Get {current_index}/{len(historical)}')
    file_path = f'{output_folder}/historical/{symbol_id}.csv'
    (existing_content, start_date) = get_existing_content(file_path)
    if (start_date):
        print(f'File {symbol_id} exists, start date is {start_date}')
    else:
        start_date = first_date
        print(f'File {symbol_id} does not exist')
    end_date = date.today()
    if (start_date >= end_date):
        print(f'Skip {symbol_id}, start is on or after end')
        continue
    print(f'Get {symbol_id} from {start_date} to {end_date}')
    new_content = coinapi_fetcher.get_history(symbol_id, start_date)
    # Make sure that content was returned before we concat an empty DF (which would fail)
    if (not new_content.empty):
        data = pd.concat([df for df in [existing_content, new_content] if not df.empty])
        write_file(data, file_path)
    time.sleep(0.5)
print(f'Out of {len(historical)} cryptos, {current_index} were fetched')
# Out:
# ------
# Get 1/401
# File ../coinapi_data/historical/COINBASE_SPOT_BTC_USD.csv exists, get last row
# Existing file has 3863 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_BTC_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_BTC_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_BTC_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_BTC_USD.csv with 3913 rows
# ------
# Get 2/401
# File ../coinapi_data/historical/COINBASE_SPOT_ETH_USD.csv exists, get last row
# Existing file has 3333 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_ETH_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_ETH_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_ETH_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_ETH_USD.csv with 3383 rows
# ------
# Get 3/401
# File ../coinapi_data/historical/COINBASE_SPOT_LTC_USD.csv exists, get last row
# Existing file has 3242 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_LTC_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_LTC_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_LTC_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_LTC_USD.csv with 3292 rows
# ------
# Get 4/401
# File ../coinapi_data/historical/COINBASE_SPOT_BCH_USD.csv exists, get last row
# Existing file has 2788 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_BCH_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_BCH_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_BCH_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_BCH_USD.csv with 2838 rows
# ------
# Get 5/401
# File ../coinapi_data/historical/COINBASE_SPOT_ETC_USD.csv exists, get last row
# Existing file has 2560 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_ETC_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_ETC_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_ETC_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_ETC_USD.csv with 2610 rows
# ------
# Get 6/401
# File ../coinapi_data/historical/COINBASE_SPOT_ZRX_USD.csv exists, get last row
# Existing file has 2497 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_ZRX_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_ZRX_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_ZRX_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_ZRX_USD.csv with 2547 rows
# ------
# Get 7/401
# File ../coinapi_data/historical/COINBASE_SPOT_XRP_USD.csv exists, get last row
# Existing file has 1459 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_XRP_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_XRP_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_XRP_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_XRP_USD.csv with 1509 rows
# ------
# Get 8/401
# File ../coinapi_data/historical/COINBASE_SPOT_XLM_USD.csv exists, get last row
# Existing file has 2344 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_XLM_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_XLM_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_XLM_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_XLM_USD.csv with 2394 rows
# ------
# Get 9/401
# File ../coinapi_data/historical/COINBASE_SPOT_EOS_USD.csv exists, get last row
# Existing file has 2318 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_EOS_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_EOS_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_EOS_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_EOS_USD.csv with 2368 rows
# ------
# Get 10/401
# File ../coinapi_data/historical/COINBASE_SPOT_REP_USD.csv exists, get last row
# Existing file has 1395 rows
# Last date in existing file is 2023-02-08
# File COINBASE_SPOT_REP_USD exists, start date is 2023-02-08
# Get COINBASE_SPOT_REP_USD from 2023-02-08 to 2025-10-13
# Fetching COINBASE_SPOT_REP_USD from 2023-02-08 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_REP_USD.csv with 1445 rows
# ------
# Get 11/401
# File ../coinapi_data/historical/COINBASE_SPOT_LINK_USD.csv exists, get last row
# Existing file has 2238 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_LINK_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_LINK_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_LINK_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_LINK_USD.csv with 2288 rows
# ------
# Get 12/401
# File ../coinapi_data/historical/COINBASE_SPOT_XTZ_USD.csv exists, get last row
# Existing file has 2197 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_XTZ_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_XTZ_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_XTZ_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_XTZ_USD.csv with 2247 rows
# ------
# Get 13/401
# File ../coinapi_data/historical/COINBASE_SPOT_ALGO_USD.csv exists, get last row
# Existing file has 2189 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_ALGO_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_ALGO_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_ALGO_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_ALGO_USD.csv with 2239 rows
# ------
# Get 14/401
# File ../coinapi_data/historical/COINBASE_SPOT_DASH_USD.csv exists, get last row
# Existing file has 2156 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_DASH_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_DASH_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_DASH_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_DASH_USD.csv with 2206 rows
# ------
# Get 15/401
# File ../coinapi_data/historical/COINBASE_SPOT_OXT_USD.csv exists, get last row
# Existing file has 2067 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_OXT_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_OXT_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_OXT_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_OXT_USD.csv with 2117 rows
# ------
# Get 16/401
# File ../coinapi_data/historical/COINBASE_SPOT_ATOM_USD.csv exists, get last row
# Existing file has 2039 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_ATOM_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_ATOM_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_ATOM_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_ATOM_USD.csv with 2089 rows
# ------
# Get 17/401
# File ../coinapi_data/historical/COINBASE_SPOT_KNC_USD.csv exists, get last row
# Existing file has 1994 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_KNC_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_KNC_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_KNC_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_KNC_USD.csv with 2044 rows
# ------
# Get 18/401
# File ../coinapi_data/historical/COINBASE_SPOT_DAI_USD.csv exists, get last row
# Existing file has 1932 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_DAI_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_DAI_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_DAI_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_DAI_USD.csv with 1982 rows
# ------
# Get 19/401
# File ../coinapi_data/historical/COINBASE_SPOT_OMG_USD.csv exists, get last row
# Existing file has 988 rows
# Last date in existing file is 2023-02-08
# File COINBASE_SPOT_OMG_USD exists, start date is 2023-02-08
# Get COINBASE_SPOT_OMG_USD from 2023-02-08 to 2025-10-13
# Fetching COINBASE_SPOT_OMG_USD from 2023-02-08 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_OMG_USD.csv with 1038 rows
# ------
# Get 20/401
# File ../coinapi_data/historical/COINBASE_SPOT_MKR_USD.csv exists, get last row
# Existing file has 1892 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_MKR_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_MKR_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_MKR_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_MKR_USD.csv with 1942 rows
# ------
# Get 21/401
# File ../coinapi_data/historical/COINBASE_SPOT_COMP_USD.csv exists, get last row
# Existing file has 1877 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_COMP_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_COMP_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_COMP_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_COMP_USD.csv with 1927 rows
# ------
# Get 22/401
# File ../coinapi_data/historical/COINBASE_SPOT_BAND_USD.csv exists, get last row
# Existing file has 1828 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_BAND_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_BAND_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_BAND_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_BAND_USD.csv with 1878 rows
# ------
# Get 23/401
# File ../coinapi_data/historical/COINBASE_SPOT_NMR_USD.csv exists, get last row
# Existing file has 1822 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_NMR_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_NMR_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_NMR_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_NMR_USD.csv with 1872 rows
# ------
# Get 24/401
# File ../coinapi_data/historical/COINBASE_SPOT_CGLD_USD.csv exists, get last row
# Existing file has 1805 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_CGLD_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_CGLD_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_CGLD_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_CGLD_USD.csv with 1855 rows
# ------
# Get 25/401
# File ../coinapi_data/historical/COINBASE_SPOT_UMA_USD.csv exists, get last row
# Existing file has 1802 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_UMA_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_UMA_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_UMA_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_UMA_USD.csv with 1852 rows
# ------
# Get 26/401
# File ../coinapi_data/historical/COINBASE_SPOT_LRC_USD.csv exists, get last row
# Existing file has 1794 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_LRC_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_LRC_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_LRC_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_LRC_USD.csv with 1844 rows
# ------
# Get 27/401
# File ../coinapi_data/historical/COINBASE_SPOT_YFI_USD.csv exists, get last row
# Existing file has 1793 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_YFI_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_YFI_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_YFI_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_YFI_USD.csv with 1843 rows
# ------
# Get 28/401
# File ../coinapi_data/historical/COINBASE_SPOT_UNI_USD.csv exists, get last row
# Existing file has 1792 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_UNI_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_UNI_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_UNI_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_UNI_USD.csv with 1842 rows
# ------
# Get 29/401
# File ../coinapi_data/historical/COINBASE_SPOT_REN_USD.csv exists, get last row
# Existing file has 1067 rows
# Last date in existing file is 2023-09-15
# File COINBASE_SPOT_REN_USD exists, start date is 2023-09-15
# Get COINBASE_SPOT_REN_USD from 2023-09-15 to 2025-10-13
# Fetching COINBASE_SPOT_REN_USD from 2023-09-15 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_REN_USD.csv with 1117 rows
# ------
# Get 30/401
# File ../coinapi_data/historical/COINBASE_SPOT_BAL_USD.csv exists, get last row
# Existing file has 1772 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_BAL_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_BAL_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_BAL_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_BAL_USD.csv with 1822 rows
# ------
# Get 31/401
# File ../coinapi_data/historical/COINBASE_SPOT_WBTC_USD.csv exists, get last row
# Existing file has 1461 rows
# Last date in existing file is 2024-10-31
# File COINBASE_SPOT_WBTC_USD exists, start date is 2024-10-31
# Get COINBASE_SPOT_WBTC_USD from 2024-10-31 to 2025-10-13
# Fetching COINBASE_SPOT_WBTC_USD from 2024-10-31 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_WBTC_USD.csv with 1511 rows
# ------
# Get 32/401
# File ../coinapi_data/historical/COINBASE_SPOT_NU_USD.csv exists, get last row
# Existing file has 741 rows
# Last date in existing file is 2022-12-19
# File COINBASE_SPOT_NU_USD exists, start date is 2022-12-19
# Get COINBASE_SPOT_NU_USD from 2022-12-19 to 2025-10-13
# Fetching COINBASE_SPOT_NU_USD from 2022-12-19 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_NU_USD.csv with 791 rows
# ------
# Get 33/401
# File ../coinapi_data/historical/COINBASE_SPOT_FIL_USD.csv exists, get last row
# Existing file has 1709 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_FIL_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_FIL_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_FIL_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_FIL_USD.csv with 1759 rows
# ------
# Get 34/401
# File ../coinapi_data/historical/COINBASE_SPOT_ZEC_USD.csv exists, get last row
# Existing file has 1710 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_ZEC_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_ZEC_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_ZEC_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_ZEC_USD.csv with 1760 rows
# ------
# Get 35/401
# File ../coinapi_data/historical/COINBASE_SPOT_BNT_USD.csv exists, get last row
# Existing file has 1701 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_BNT_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_BNT_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_BNT_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_BNT_USD.csv with 1751 rows
# ------
# Get 36/401
# File ../coinapi_data/historical/COINBASE_SPOT_SNX_USD.csv exists, get last row
# Existing file has 1703 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_SNX_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_SNX_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_SNX_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_SNX_USD.csv with 1753 rows
# ------
# Get 37/401
# File ../coinapi_data/historical/COINBASE_SPOT_AAVE_USD.csv exists, get last row
# Existing file has 1703 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_AAVE_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_AAVE_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_AAVE_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_AAVE_USD.csv with 1753 rows
# ------
# Get 38/401
# File ../coinapi_data/historical/COINBASE_SPOT_GRT_USD.csv exists, get last row
# Existing file has 1699 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_GRT_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_GRT_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_GRT_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_GRT_USD.csv with 1749 rows
# ------
# Get 39/401
# File ../coinapi_data/historical/COINBASE_SPOT_SUSHI_USD.csv exists, get last row
# Existing file has 1617 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_SUSHI_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_SUSHI_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_SUSHI_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_SUSHI_USD.csv with 1667 rows
# ------
# Get 40/401
# File ../coinapi_data/historical/COINBASE_SPOT_MATIC_USD.csv exists, get last row
# Existing file has 1616 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_MATIC_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_MATIC_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_MATIC_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_MATIC_USD.csv with 1666 rows
# ------
# Get 41/401
# File ../coinapi_data/historical/COINBASE_SPOT_SKL_USD.csv exists, get last row
# Existing file has 1617 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_SKL_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_SKL_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_SKL_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_SKL_USD.csv with 1667 rows
# ------
# Get 42/401
# File ../coinapi_data/historical/COINBASE_SPOT_ADA_USD.csv exists, get last row
# Existing file has 1609 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_ADA_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_ADA_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_ADA_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_ADA_USD.csv with 1659 rows
# ------
# Get 43/401
# File ../coinapi_data/historical/COINBASE_SPOT_CRV_USD.csv exists, get last row
# Existing file has 1605 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_CRV_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_CRV_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_CRV_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_CRV_USD.csv with 1655 rows
# ------
# Get 44/401
# File ../coinapi_data/historical/COINBASE_SPOT_STORJ_USD.csv exists, get last row
# Existing file has 1605 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_STORJ_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_STORJ_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_STORJ_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_STORJ_USD.csv with 1655 rows
# ------
# Get 45/401
# File ../coinapi_data/historical/COINBASE_SPOT_ANKR_USD.csv exists, get last row
# Existing file has 1605 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_ANKR_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_ANKR_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_ANKR_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_ANKR_USD.csv with 1655 rows
# ------
# Get 46/401
# File ../coinapi_data/historical/COINBASE_SPOT_OGN_USD.csv exists, get last row
# Existing file has 1591 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_OGN_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_OGN_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_OGN_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_OGN_USD.csv with 1641 rows
# ------
# Get 47/401
# File ../coinapi_data/historical/COINBASE_SPOT_ENJ_USD.csv exists, get last row
# Existing file has 1107 rows
# Last date in existing file is 2024-04-23
# File COINBASE_SPOT_ENJ_USD exists, start date is 2024-04-23
# Get COINBASE_SPOT_ENJ_USD from 2024-04-23 to 2025-10-13
# Fetching COINBASE_SPOT_ENJ_USD from 2024-04-23 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_ENJ_USD.csv with 1157 rows
# ------
# Get 48/401
# File ../coinapi_data/historical/COINBASE_SPOT_1INCH_USD.csv exists, get last row
# Existing file has 1591 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_1INCH_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_1INCH_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_1INCH_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_1INCH_USD.csv with 1641 rows
# ------
# Get 49/401
# File ../coinapi_data/historical/COINBASE_SPOT_NKN_USD.csv exists, get last row
# Existing file has 1591 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_NKN_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_NKN_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_NKN_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_NKN_USD.csv with 1641 rows
# ------
# Get 50/401
# File ../coinapi_data/historical/COINBASE_SPOT_BAT_USD.csv exists, get last row
# Existing file has 1579 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_BAT_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_BAT_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_BAT_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_BAT_USD.csv with 1629 rows
# ------
# Get 51/401
# File ../coinapi_data/historical/COINBASE_SPOT_MANA_USD.csv exists, get last row
# Existing file has 1581 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_MANA_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_MANA_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_MANA_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_MANA_USD.csv with 1631 rows
# ------
# Get 52/401
# File ../coinapi_data/historical/COINBASE_SPOT_FORTH_USD.csv exists, get last row
# Existing file has 1579 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_FORTH_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_FORTH_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_FORTH_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_FORTH_USD.csv with 1629 rows
# ------
# Get 53/401
# File ../coinapi_data/historical/COINBASE_SPOT_USDT_USD.csv exists, get last row
# Existing file has 1567 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_USDT_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_USDT_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_USDT_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_USDT_USD.csv with 1617 rows
# ------
# Get 54/401
# File ../coinapi_data/historical/COINBASE_SPOT_TRB_USD.csv exists, get last row
# Existing file has 1565 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_TRB_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_TRB_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_TRB_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_TRB_USD.csv with 1615 rows
# ------
# Get 55/401
# File ../coinapi_data/historical/COINBASE_SPOT_RLC_USD.csv exists, get last row
# Existing file has 1562 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_RLC_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_RLC_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_RLC_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_RLC_USD.csv with 1612 rows
# ------
# Get 56/401
# File ../coinapi_data/historical/COINBASE_SPOT_MIR_USD.csv exists, get last row
# Existing file has 642 rows
# Last date in existing file is 2023-02-08
# File COINBASE_SPOT_MIR_USD exists, start date is 2023-02-08
# Get COINBASE_SPOT_MIR_USD from 2023-02-08 to 2025-10-13
# Fetching COINBASE_SPOT_MIR_USD from 2023-02-08 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_MIR_USD.csv with 692 rows
# ------
# Get 57/401
# File ../coinapi_data/historical/COINBASE_SPOT_CTSI_USD.csv exists, get last row
# Existing file has 1564 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_CTSI_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_CTSI_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_CTSI_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_CTSI_USD.csv with 1614 rows
# ------
# Get 58/401
# File ../coinapi_data/historical/COINBASE_SPOT_ICP_USD.csv exists, get last row
# Existing file has 1561 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_ICP_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_ICP_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_ICP_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_ICP_USD.csv with 1611 rows
# ------
# Get 59/401
# File ../coinapi_data/historical/COINBASE_SPOT_SOL_USD.csv exists, get last row
# Existing file has 1523 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_SOL_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_SOL_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_SOL_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_SOL_USD.csv with 1573 rows
# ------
# Get 60/401
# File ../coinapi_data/historical/COINBASE_SPOT_DOGE_USD.csv exists, get last row
# Existing file has 1537 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_DOGE_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_DOGE_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_DOGE_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_DOGE_USD.csv with 1587 rows
# ------
# Get 61/401
# File ../coinapi_data/historical/COINBASE_SPOT_AMP_USD.csv exists, get last row
# Existing file has 1530 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_AMP_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_AMP_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_AMP_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_AMP_USD.csv with 1580 rows
# ------
# Get 62/401
# File ../coinapi_data/historical/COINBASE_SPOT_MLN_USD.csv exists, get last row
# Existing file has 1529 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_MLN_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_MLN_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_MLN_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_MLN_USD.csv with 1579 rows
# ------
# Get 63/401
# File ../coinapi_data/historical/COINBASE_SPOT_GTC_USD.csv exists, get last row
# Existing file has 1529 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_GTC_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_GTC_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_GTC_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_GTC_USD.csv with 1579 rows
# ------
# Get 64/401
# File ../coinapi_data/historical/COINBASE_SPOT_DOT_USD.csv exists, get last row
# Existing file has 1523 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_DOT_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_DOT_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_DOT_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_DOT_USD.csv with 1573 rows
# ------
# Get 65/401
# File ../coinapi_data/historical/COINBASE_SPOT_CHZ_USD.csv exists, get last row
# Existing file has 1522 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_CHZ_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_CHZ_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_CHZ_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_CHZ_USD.csv with 1572 rows
# ------
# Get 66/401
# File ../coinapi_data/historical/COINBASE_SPOT_SHIB_USD.csv exists, get last row
# Existing file has 1438 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_SHIB_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_SHIB_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_SHIB_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_SHIB_USD.csv with 1488 rows
# ------
# Get 67/401
# File ../coinapi_data/historical/COINBASE_SPOT_KEEP_USD.csv exists, get last row
# Existing file has 549 rows
# Last date in existing file is 2022-12-19
# File COINBASE_SPOT_KEEP_USD exists, start date is 2022-12-19
# Get COINBASE_SPOT_KEEP_USD from 2022-12-19 to 2025-10-13
# Fetching COINBASE_SPOT_KEEP_USD from 2022-12-19 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_KEEP_USD.csv with 599 rows
# ------
# Get 68/401
# File ../coinapi_data/historical/COINBASE_SPOT_BOND_USD.csv exists, get last row
# Existing file has 752 rows
# Last date in existing file is 2023-07-17
# File COINBASE_SPOT_BOND_USD exists, start date is 2023-07-17
# Get COINBASE_SPOT_BOND_USD from 2023-07-17 to 2025-10-13
# Fetching COINBASE_SPOT_BOND_USD from 2023-07-17 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_BOND_USD.csv with 802 rows
# ------
# Get 69/401
# File ../coinapi_data/historical/COINBASE_SPOT_LPT_USD.csv exists, get last row
# Existing file has 1514 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_LPT_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_LPT_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_LPT_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_LPT_USD.csv with 1564 rows
# ------
# Get 70/401
# File ../coinapi_data/historical/COINBASE_SPOT_QNT_USD.csv exists, get last row
# Existing file has 1516 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_QNT_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_QNT_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_QNT_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_QNT_USD.csv with 1566 rows
# ------
# Get 71/401
# File ../coinapi_data/historical/COINBASE_SPOT_RLY_USD.csv exists, get last row
# Existing file has 572 rows
# Last date in existing file is 2023-02-08
# File COINBASE_SPOT_RLY_USD exists, start date is 2023-02-08
# Get COINBASE_SPOT_RLY_USD from 2023-02-08 to 2025-10-13
# Fetching COINBASE_SPOT_RLY_USD from 2023-02-08 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_RLY_USD.csv with 622 rows
# ------
# Get 72/401
# File ../coinapi_data/historical/COINBASE_SPOT_MASK_USD.csv exists, get last row
# Existing file has 1495 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_MASK_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_MASK_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_MASK_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_MASK_USD.csv with 1545 rows
# ------
# Get 73/401
# File ../coinapi_data/historical/COINBASE_SPOT_CLV_USD.csv exists, get last row
# Existing file has 1495 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_CLV_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_CLV_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_CLV_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_CLV_USD.csv with 1545 rows
# ------
# Get 74/401
# File ../coinapi_data/historical/COINBASE_SPOT_FET_USD.csv exists, get last row
# Existing file has 1483 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_FET_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_FET_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_FET_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_FET_USD.csv with 1533 rows
# ------
# Get 75/401
# File ../coinapi_data/historical/COINBASE_SPOT_PAX_USD.csv exists, get last row
# Existing file has 1476 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_PAX_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_PAX_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_PAX_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_PAX_USD.csv with 1526 rows
# ------
# Get 76/401
# File ../coinapi_data/historical/COINBASE_SPOT_FARM_USD.csv exists, get last row
# Existing file has 1479 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_FARM_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_FARM_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_FARM_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_FARM_USD.csv with 1529 rows
# ------
# Get 77/401
# File ../coinapi_data/historical/COINBASE_SPOT_POLY_USD.csv exists, get last row
# Existing file has 809 rows
# Last date in existing file is 2023-10-17
# File COINBASE_SPOT_POLY_USD exists, start date is 2023-10-17
# Get COINBASE_SPOT_POLY_USD from 2023-10-17 to 2025-10-13
# Fetching COINBASE_SPOT_POLY_USD from 2023-10-17 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_POLY_USD.csv with 859 rows
# ------
# Get 78/401
# File ../coinapi_data/historical/COINBASE_SPOT_PLA_USD.csv exists, get last row
# Existing file has 872 rows
# Last date in existing file is 2023-12-27
# File COINBASE_SPOT_PLA_USD exists, start date is 2023-12-27
# Get COINBASE_SPOT_PLA_USD from 2023-12-27 to 2025-10-13
# Fetching COINBASE_SPOT_PLA_USD from 2023-12-27 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_PLA_USD.csv with 922 rows
# ------
# Get 79/401
# File ../coinapi_data/historical/COINBASE_SPOT_ACH_USD.csv exists, get last row
# Existing file has 1476 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_ACH_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_ACH_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_ACH_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_ACH_USD.csv with 1526 rows
# ------
# Get 80/401
# File ../coinapi_data/historical/COINBASE_SPOT_RAI_USD.csv exists, get last row
# Existing file has 1025 rows
# Last date in existing file is 2024-05-31
# File COINBASE_SPOT_RAI_USD exists, start date is 2024-05-31
# Get COINBASE_SPOT_RAI_USD from 2024-05-31 to 2025-10-13
# Fetching COINBASE_SPOT_RAI_USD from 2024-05-31 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_RAI_USD.csv with 1075 rows
# ------
# Get 81/401
# File ../coinapi_data/historical/COINBASE_SPOT_TRIBE_USD.csv exists, get last row
# Existing file has 399 rows
# Last date in existing file is 2022-09-16
# File COINBASE_SPOT_TRIBE_USD exists, start date is 2022-09-16
# Get COINBASE_SPOT_TRIBE_USD from 2022-09-16 to 2025-10-13
# Fetching COINBASE_SPOT_TRIBE_USD from 2022-09-16 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_TRIBE_USD.csv with 449 rows
# ------
# Get 82/401
# File ../coinapi_data/historical/COINBASE_SPOT_UST_USD.csv exists, get last row
# Existing file has 237 rows
# Last date in existing file is 2022-04-08
# File COINBASE_SPOT_UST_USD exists, start date is 2022-04-08
# Get COINBASE_SPOT_UST_USD from 2022-04-08 to 2025-10-13
# Fetching COINBASE_SPOT_UST_USD from 2022-04-08 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_UST_USD.csv with 287 rows
# ------
# Get 83/401
# File ../coinapi_data/historical/COINBASE_SPOT_IOTX_USD.csv exists, get last row
# Existing file has 1468 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_IOTX_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_IOTX_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_IOTX_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_IOTX_USD.csv with 1518 rows
# ------
# Get 84/401
# File ../coinapi_data/historical/COINBASE_SPOT_ORN_USD.csv exists, get last row
# Existing file has 1319 rows
# Last date in existing file is 2025-03-28
# File COINBASE_SPOT_ORN_USD exists, start date is 2025-03-28
# Get COINBASE_SPOT_ORN_USD from 2025-03-28 to 2025-10-13
# Fetching COINBASE_SPOT_ORN_USD from 2025-03-28 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_ORN_USD.csv with 1369 rows
# ------
# Get 85/401
# File ../coinapi_data/historical/COINBASE_SPOT_QUICK_USD.csv exists, get last row
# Existing file has 795 rows
# Last date in existing file is 2023-10-18
# File COINBASE_SPOT_QUICK_USD exists, start date is 2023-10-18
# Get COINBASE_SPOT_QUICK_USD from 2023-10-18 to 2025-10-13
# Fetching COINBASE_SPOT_QUICK_USD from 2023-10-18 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_QUICK_USD.csv with 845 rows
# ------
# Get 86/401
# File ../coinapi_data/historical/COINBASE_SPOT_TRU_USD.csv exists, get last row
# Existing file has 1466 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_TRU_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_TRU_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_TRU_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_TRU_USD.csv with 1516 rows
# ------
# Get 87/401
# File ../coinapi_data/historical/COINBASE_SPOT_AXS_USD.csv exists, get last row
# Existing file has 1466 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_AXS_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_AXS_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_AXS_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_AXS_USD.csv with 1516 rows
# ------
# Get 88/401
# File ../coinapi_data/historical/COINBASE_SPOT_REQ_USD.csv exists, get last row
# Existing file has 1466 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_REQ_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_REQ_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_REQ_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_REQ_USD.csv with 1516 rows
# ------
# Get 89/401
# File ../coinapi_data/historical/COINBASE_SPOT_WLUNA_USD.csv exists, get last row
# Existing file has 238 rows
# Last date in existing file is 2022-04-08
# File COINBASE_SPOT_WLUNA_USD exists, start date is 2022-04-08
# Get COINBASE_SPOT_WLUNA_USD from 2022-04-08 to 2025-10-13
# Fetching COINBASE_SPOT_WLUNA_USD from 2022-04-08 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_WLUNA_USD.csv with 288 rows
# ------
# Get 90/401
# File ../coinapi_data/historical/COINBASE_SPOT_COTI_USD.csv exists, get last row
# Existing file has 1453 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_COTI_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_COTI_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_COTI_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_COTI_USD.csv with 1503 rows
# ------
# Get 91/401
# File ../coinapi_data/historical/COINBASE_SPOT_DDX_USD.csv exists, get last row
# Existing file has 682 rows
# Last date in existing file is 2023-07-17
# File COINBASE_SPOT_DDX_USD exists, start date is 2023-07-17
# Get COINBASE_SPOT_DDX_USD from 2023-07-17 to 2025-10-13
# Fetching COINBASE_SPOT_DDX_USD from 2023-07-17 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_DDX_USD.csv with 732 rows
# ------
# Get 92/401
# File ../coinapi_data/historical/COINBASE_SPOT_RAD_USD.csv exists, get last row
# Existing file has 1446 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_RAD_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_RAD_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_RAD_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_RAD_USD.csv with 1496 rows
# ------
# Get 93/401
# File ../coinapi_data/historical/COINBASE_SPOT_YFII_USD.csv exists, get last row
# Existing file has 523 rows
# Last date in existing file is 2023-02-08
# File COINBASE_SPOT_YFII_USD exists, start date is 2023-02-08
# Get COINBASE_SPOT_YFII_USD from 2023-02-08 to 2025-10-13
# Fetching COINBASE_SPOT_YFII_USD from 2023-02-08 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_YFII_USD.csv with 573 rows
# ------
# Get 94/401
# File ../coinapi_data/historical/COINBASE_SPOT_XYO_USD.csv exists, get last row
# Existing file has 1439 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_XYO_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_XYO_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_XYO_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_XYO_USD.csv with 1489 rows
# ------
# Get 95/401
# File ../coinapi_data/historical/COINBASE_SPOT_RGT_USD.csv exists, get last row
# Existing file has 371 rows
# Last date in existing file is 2022-09-16
# File COINBASE_SPOT_RGT_USD exists, start date is 2022-09-16
# Get COINBASE_SPOT_RGT_USD from 2022-09-16 to 2025-10-13
# Fetching COINBASE_SPOT_RGT_USD from 2022-09-16 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_RGT_USD.csv with 421 rows
# ------
# Get 96/401
# File ../coinapi_data/historical/COINBASE_SPOT_BTRST_USD.csv exists, get last row
# Existing file has 1433 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_BTRST_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_BTRST_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_BTRST_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_BTRST_USD.csv with 1483 rows
# ------
# Get 97/401
# File ../coinapi_data/historical/COINBASE_SPOT_ZEN_USD.csv exists, get last row
# Existing file has 1421 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_ZEN_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_ZEN_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_ZEN_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_ZEN_USD.csv with 1471 rows
# ------
# Get 98/401
# File ../coinapi_data/historical/COINBASE_SPOT_AGLD_USD.csv exists, get last row
# Existing file has 1427 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_AGLD_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_AGLD_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_AGLD_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_AGLD_USD.csv with 1477 rows
# ------
# Get 99/401
# File ../coinapi_data/historical/COINBASE_SPOT_AVAX_USD.csv exists, get last row
# Existing file has 1418 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_AVAX_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_AVAX_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_AVAX_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_AVAX_USD.csv with 1468 rows
# ------
# Get 100/401
# File ../coinapi_data/historical/COINBASE_SPOT_FX_USD.csv exists, get last row
# Existing file has 1352 rows
# Last date in existing file is 2025-06-27
# File COINBASE_SPOT_FX_USD exists, start date is 2025-06-27
# Get COINBASE_SPOT_FX_USD from 2025-06-27 to 2025-10-13
# Fetching COINBASE_SPOT_FX_USD from 2025-06-27 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_FX_USD.csv with 1402 rows
# ------
# Get 101/401
# File ../coinapi_data/historical/COINBASE_SPOT_JASMY_USD.csv exists, get last row
# Existing file has 1411 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_JASMY_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_JASMY_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_JASMY_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_JASMY_USD.csv with 1461 rows
# ------
# Get 102/401
# File COINBASE_SPOT_TBTC_USD does not exist
# Get COINBASE_SPOT_TBTC_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_TBTC_USD from 2010-01-01 to 2025-10-13 …
# Fetched 0 bars
# ------
# Get 103/401
# File ../coinapi_data/historical/COINBASE_SPOT_WCFG_USD.csv exists, get last row
# Existing file has 1410 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_WCFG_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_WCFG_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_WCFG_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_WCFG_USD.csv with 1460 rows
# ------
# Get 104/401
# File ../coinapi_data/historical/COINBASE_SPOT_BADGER_USD.csv exists, get last row
# Existing file has 1404 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_BADGER_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_BADGER_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_BADGER_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_BADGER_USD.csv with 1454 rows
# ------
# Get 105/401
# File ../coinapi_data/historical/COINBASE_SPOT_RARI_USD.csv exists, get last row
# Existing file has 1403 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_RARI_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_RARI_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_RARI_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_RARI_USD.csv with 1453 rows
# ------
# Get 106/401
# File ../coinapi_data/historical/COINBASE_SPOT_PERP_USD.csv exists, get last row
# Existing file has 1398 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_PERP_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_PERP_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_PERP_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_PERP_USD.csv with 1448 rows
# ------
# Get 107/401
# File ../coinapi_data/historical/COINBASE_SPOT_ARPA_USD.csv exists, get last row
# Existing file has 1399 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_ARPA_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_ARPA_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_ARPA_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_ARPA_USD.csv with 1449 rows
# ------
# Get 108/401
# File ../coinapi_data/historical/COINBASE_SPOT_AUCTION_USD.csv exists, get last row
# Existing file has 1399 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_AUCTION_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_AUCTION_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_AUCTION_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_AUCTION_USD.csv with 1449 rows
# ------
# Get 109/401
# File ../coinapi_data/historical/COINBASE_SPOT_ASM_USD.csv exists, get last row
# Existing file has 1397 rows
# Last date in existing file is 2025-08-24
# File COINBASE_SPOT_ASM_USD exists, start date is 2025-08-24
# Get COINBASE_SPOT_ASM_USD from 2025-08-24 to 2025-10-13
# Fetching COINBASE_SPOT_ASM_USD from 2025-08-24 to 2025-10-13 …
# Fetched 50 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_ASM_USD.csv with 1447 rows
# ------
# Get 110/401
# ...
# Fetching COINBASE_SPOT_FARTCOIN_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_FARTCOIN_USD.csv with 123 rows
# ------
# Get 363/401
# File ../coinapi_data/historical/COINBASE_SPOT_SPK_USD.csv exists, get last row
# Existing file has 64 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_SPK_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_SPK_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_SPK_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_SPK_USD.csv with 118 rows
# ------
# Get 364/401
# File ../coinapi_data/historical/COINBASE_SPOT_S_USD.csv exists, get last row
# Existing file has 57 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_S_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_S_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_S_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_S_USD.csv with 111 rows
# ------
# Get 365/401
# File ../coinapi_data/historical/COINBASE_SPOT_NEWT_USD.csv exists, get last row
# Existing file has 57 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_NEWT_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_NEWT_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_NEWT_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_NEWT_USD.csv with 111 rows
# ------
# Get 366/401
# File ../coinapi_data/historical/COINBASE_SPOT_W_USD.csv exists, get last row
# Existing file has 49 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_W_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_W_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_W_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_W_USD.csv with 103 rows
# ------
# Get 367/401
# File ../coinapi_data/historical/COINBASE_SPOT_SKY_USD.csv exists, get last row
# Existing file has 41 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_SKY_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_SKY_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_SKY_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_SKY_USD.csv with 95 rows
# ------
# Get 368/401
# File ../coinapi_data/historical/COINBASE_SPOT_USDS_USD.csv exists, get last row
# Existing file has 41 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_USDS_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_USDS_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_USDS_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_USDS_USD.csv with 95 rows
# ------
# Get 369/401
# File ../coinapi_data/historical/COINBASE_SPOT_PUMP_USD.csv exists, get last row
# Existing file has 36 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_PUMP_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_PUMP_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_PUMP_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_PUMP_USD.csv with 90 rows
# ------
# Get 370/401
# File ../coinapi_data/historical/COINBASE_SPOT_ERA_USD.csv exists, get last row
# Existing file has 34 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_ERA_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_ERA_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_ERA_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_ERA_USD.csv with 88 rows
# ------
# Get 371/401
# File ../coinapi_data/historical/COINBASE_SPOT_JITOSOL_USD.csv exists, get last row
# Existing file has 27 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_JITOSOL_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_JITOSOL_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_JITOSOL_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_JITOSOL_USD.csv with 81 rows
# ------
# Get 372/401
# File ../coinapi_data/historical/COINBASE_SPOT_MPLX_USD.csv exists, get last row
# Existing file has 27 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_MPLX_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_MPLX_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_MPLX_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_MPLX_USD.csv with 81 rows
# ------
# Get 373/401
# File ../coinapi_data/historical/COINBASE_SPOT_TREE_USD.csv exists, get last row
# Existing file has 22 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_TREE_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_TREE_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_TREE_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_TREE_USD.csv with 76 rows
# ------
# Get 374/401
# File ../coinapi_data/historical/COINBASE_SPOT_BNKR_USD.csv exists, get last row
# Existing file has 21 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_BNKR_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_BNKR_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_BNKR_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_BNKR_USD.csv with 75 rows
# ------
# Get 375/401
# File ../coinapi_data/historical/COINBASE_SPOT_BIO_USD.csv exists, get last row
# Existing file has 20 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_BIO_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_BIO_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_BIO_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_BIO_USD.csv with 74 rows
# ------
# Get 376/401
# File ../coinapi_data/historical/COINBASE_SPOT_RSC_USD.csv exists, get last row
# Existing file has 20 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_RSC_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_RSC_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_RSC_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_RSC_USD.csv with 74 rows
# ------
# Get 377/401
# File ../coinapi_data/historical/COINBASE_SPOT_MAMO_USD.csv exists, get last row
# Existing file has 14 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_MAMO_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_MAMO_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_MAMO_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_MAMO_USD.csv with 68 rows
# ------
# Get 378/401
# File ../coinapi_data/historical/COINBASE_SPOT_EUL_USD.csv exists, get last row
# Existing file has 14 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_EUL_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_EUL_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_EUL_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_EUL_USD.csv with 68 rows
# ------
# Get 379/401
# File ../coinapi_data/historical/COINBASE_SPOT_PROVE_USD.csv exists, get last row
# Existing file has 15 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_PROVE_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_PROVE_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_PROVE_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_PROVE_USD.csv with 69 rows
# ------
# Get 380/401
# File ../coinapi_data/historical/COINBASE_SPOT_TOWNS_USD.csv exists, get last row
# Existing file has 15 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_TOWNS_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_TOWNS_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_TOWNS_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_TOWNS_USD.csv with 69 rows
# ------
# Get 381/401
# File ../coinapi_data/historical/COINBASE_SPOT_COSMOSDYDX_USD.csv exists, get last row
# Existing file has 13 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_COSMOSDYDX_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_COSMOSDYDX_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_COSMOSDYDX_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_COSMOSDYDX_USD.csv with 67 rows
# ------
# Get 382/401
# File ../coinapi_data/historical/COINBASE_SPOT_WCT_USD.csv exists, get last row
# Existing file has 6 rows
# Last date in existing file is 2025-08-20
# File COINBASE_SPOT_WCT_USD exists, start date is 2025-08-20
# Get COINBASE_SPOT_WCT_USD from 2025-08-20 to 2025-10-13
# Fetching COINBASE_SPOT_WCT_USD from 2025-08-20 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_WCT_USD.csv with 60 rows
# ------
# Get 383/401
# File ../coinapi_data/historical/COINBASE_SPOT_USELESS_USD.csv exists, get last row
# Existing file has 0 rows
# File COINBASE_SPOT_USELESS_USD does not exist
# Get COINBASE_SPOT_USELESS_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_USELESS_USD from 2010-01-01 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_USELESS_USD.csv with 54 rows
# ------
# Get 384/401
# File ../coinapi_data/historical/COINBASE_SPOT_SAPIEN_USD.csv exists, get last row
# Existing file has 0 rows
# File COINBASE_SPOT_SAPIEN_USD does not exist
# Get COINBASE_SPOT_SAPIEN_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_SAPIEN_USD from 2010-01-01 to 2025-10-13 …
# Fetched 54 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_SAPIEN_USD.csv with 54 rows
# ------
# Get 385/401
# File ../coinapi_data/historical/COINBASE_SPOT_USD1_USD.csv exists, get last row
# Existing file has 0 rows
# File COINBASE_SPOT_USD1_USD does not exist
# Get COINBASE_SPOT_USD1_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_USD1_USD from 2010-01-01 to 2025-10-13 …
# Fetched 53 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_USD1_USD.csv with 53 rows
# ------
# Get 386/401
# File ../coinapi_data/historical/COINBASE_SPOT_WLFI_USD.csv exists, get last row
# Existing file has 0 rows
# File COINBASE_SPOT_WLFI_USD does not exist
# Get COINBASE_SPOT_WLFI_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_WLFI_USD from 2010-01-01 to 2025-10-13 …
# Fetched 42 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_WLFI_USD.csv with 42 rows
# ------
# Get 387/401
# File ../coinapi_data/historical/COINBASE_SPOT_AWE_USD.csv exists, get last row
# Existing file has 0 rows
# File COINBASE_SPOT_AWE_USD does not exist
# Get COINBASE_SPOT_AWE_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_AWE_USD from 2010-01-01 to 2025-10-13 …
# Fetched 39 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_AWE_USD.csv with 39 rows
# ------
# Get 388/401
# File ../coinapi_data/historical/COINBASE_SPOT_FLOCK_USD.csv exists, get last row
# Existing file has 0 rows
# File COINBASE_SPOT_FLOCK_USD does not exist
# Get COINBASE_SPOT_FLOCK_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_FLOCK_USD from 2010-01-01 to 2025-10-13 …
# Fetched 34 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_FLOCK_USD.csv with 34 rows
# ------
# Get 389/401
# File ../coinapi_data/historical/COINBASE_SPOT_SPX_USD.csv exists, get last row
# Existing file has 0 rows
# File COINBASE_SPOT_SPX_USD does not exist
# Get COINBASE_SPOT_SPX_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_SPX_USD from 2010-01-01 to 2025-10-13 …
# Fetched 34 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_SPX_USD.csv with 34 rows
# ------
# Get 390/401
# File ../coinapi_data/historical/COINBASE_SPOT_AVNT_USD.csv exists, get last row
# Existing file has 0 rows
# File COINBASE_SPOT_AVNT_USD does not exist
# Get COINBASE_SPOT_AVNT_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_AVNT_USD from 2010-01-01 to 2025-10-13 …
# Fetched 34 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_AVNT_USD.csv with 34 rows
# ------
# Get 391/401
# File ../coinapi_data/historical/COINBASE_SPOT_DOLO_USD.csv exists, get last row
# Existing file has 0 rows
# File COINBASE_SPOT_DOLO_USD does not exist
# Get COINBASE_SPOT_DOLO_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_DOLO_USD from 2010-01-01 to 2025-10-13 …
# Fetched 32 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_DOLO_USD.csv with 32 rows
# ------
# Get 392/401
# File ../coinapi_data/historical/COINBASE_SPOT_KMNO_USD.csv exists, get last row
# Existing file has 0 rows
# File COINBASE_SPOT_KMNO_USD does not exist
# Get COINBASE_SPOT_KMNO_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_KMNO_USD from 2010-01-01 to 2025-10-13 …
# Fetched 32 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_KMNO_USD.csv with 32 rows
# ------
# Get 393/401
# File ../coinapi_data/historical/COINBASE_SPOT_LAYER_USD.csv exists, get last row
# Existing file has 0 rows
# File COINBASE_SPOT_LAYER_USD does not exist
# Get COINBASE_SPOT_LAYER_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_LAYER_USD from 2010-01-01 to 2025-10-13 …
# Fetched 32 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_LAYER_USD.csv with 32 rows
# ------
# Get 394/401
# File ../coinapi_data/historical/COINBASE_SPOT_ZKC_USD.csv exists, get last row
# Existing file has 0 rows
# File COINBASE_SPOT_ZKC_USD does not exist
# Get COINBASE_SPOT_ZKC_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_ZKC_USD from 2010-01-01 to 2025-10-13 …
# Fetched 28 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_ZKC_USD.csv with 28 rows
# ------
# Get 395/401
# File ../coinapi_data/historical/COINBASE_SPOT_BARD_USD.csv exists, get last row
# Existing file has 0 rows
# File COINBASE_SPOT_BARD_USD does not exist
# Get COINBASE_SPOT_BARD_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_BARD_USD from 2010-01-01 to 2025-10-13 …
# Fetched 25 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_BARD_USD.csv with 25 rows
# ------
# Get 396/401
# File ../coinapi_data/historical/COINBASE_SPOT_CFG_USD.csv exists, get last row
# Existing file has 0 rows
# File COINBASE_SPOT_CFG_USD does not exist
# Get COINBASE_SPOT_CFG_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_CFG_USD from 2010-01-01 to 2025-10-13 …
# Fetched 18 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_CFG_USD.csv with 18 rows
# ------
# Get 397/401
# File ../coinapi_data/historical/COINBASE_SPOT_TROLL_USD.csv exists, get last row
# Existing file has 0 rows
# File COINBASE_SPOT_TROLL_USD does not exist
# Get COINBASE_SPOT_TROLL_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_TROLL_USD from 2010-01-01 to 2025-10-13 …
# Fetched 18 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_TROLL_USD.csv with 18 rows
# ------
# Get 398/401
# File ../coinapi_data/historical/COINBASE_SPOT_XAN_USD.csv exists, get last row
# Existing file has 0 rows
# File COINBASE_SPOT_XAN_USD does not exist
# Get COINBASE_SPOT_XAN_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_XAN_USD from 2010-01-01 to 2025-10-13 …
# Fetched 14 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_XAN_USD.csv with 14 rows
# ------
# Get 399/401
# File COINBASE_SPOT_LINEA_USD does not exist
# Get COINBASE_SPOT_LINEA_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_LINEA_USD from 2010-01-01 to 2025-10-13 …
# Fetched 4 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_LINEA_USD.csv with 4 rows
# ------
# Get 400/401
# File COINBASE_SPOT_NOICE_USD does not exist
# Get COINBASE_SPOT_NOICE_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_NOICE_USD from 2010-01-01 to 2025-10-13 …
# Fetched 4 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_NOICE_USD.csv with 4 rows
# ------
# Get 401/401
# File COINBASE_SPOT_SYND_USD does not exist
# Get COINBASE_SPOT_SYND_USD from 2010-01-01 to 2025-10-13
# Fetching COINBASE_SPOT_SYND_USD from 2010-01-01 to 2025-10-13 …
# Fetched 4 bars
# Wrote file ../coinapi_data/historical/COINBASE_SPOT_SYND_USD.csv with 4 rows
# Out of 401 cryptos, 401 were fetched

# %%
# Turns out: /history returns active *and* delisted data
for symbol_id in active:
    if (symbol_id not in historical):
        print(f'!!!!! Active symbol {symbol_id} not in historical list')
#     file_path = f'{output_folder}/active/{symbol_id}.csv'
#     start_date = get_latest_entry_date(file_path) or first_date
#     end_date = date.today()
#     if (start_date >= end_date):
#         print(f'Skip {symbol_id}, start is on or after end')
#         continue
#     print(f'Get {symbol_id} from {start_date}')
#     data = coinapi_fetcher.get_history(symbol_id, start_date)
#     write_file(data, file_path)
#     time.sleep(1)

# print('Done')
